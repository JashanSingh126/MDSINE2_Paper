# %%
# Out:
# Error: Direct kernel connection broken
# at y.getDisposedError (c:\Users\microbiome\.vscode\extensions\ms-toolsai.jupyter-2020.11.399280825\out\client\extension.js:32:674486)
# at f.D.handleCodeRequest (c:\Users\microbiome\.vscode\extensions\ms-toolsai.jupyter-2020.11.399280825\out\client\extension.js:49:532850)
# at c:\Users\microbiome\.vscode\extensions\ms-toolsai.jupyter-2020.11.399280825\out\client\extension.js:49:546279

# %%
import mdsine2 as md2
import pandas as pd

import sys
sys.path.append('../')
from gibson_dataset.scripts.util import load_gibson_dataset

# df = pd.read_csv('../datasets/gibson/counts.tsv', sep='\t')
# print(df.head())

dset = load_gibson_dataset(dset='healthy')
print(dset.name)
print(dset.names())

for perturbation in dset.perturbations:
    print(perturbation)
