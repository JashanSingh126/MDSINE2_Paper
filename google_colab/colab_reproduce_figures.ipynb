# %% [markdown]
# # Figures for MDSINE2
#
# The codes below reproduce the figures appearing in the paper, "***Dynamical systems inference at scale reveals intrinsic instability in the dysbiotic microbiome***". The output figures are saved in `MDSINE2_Paper/analysis/gibson_inference/figures/output_figures/`.

# %% [markdown]
# ## Dependency Initializations

# %% [markdown]
# ### Install Necessary libraries

# %%
# !git clone https://github.com/gerberlab/MDSINE2
# !pip install MDSINE2/.
# Out:
# Cloning into 'MDSINE2'...
# remote: Enumerating objects: 2997, done.
# remote: Counting objects: 100% (906/906), done.
# remote: Compressing objects: 100% (626/626), done.
# remote: Total 2997 (delta 607), reused 531 (delta 271), pack-reused 2091
# Receiving objects: 100% (2997/2997), 78.20 MiB | 10.28 MiB/s, done.
# Resolving deltas: 100% (1897/1897), done.
# Processing ./MDSINE2
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Requirement already satisfied: numpy>=1.19.4 in /usr/local/lib/python3.7/dist-packages (from mdsine2==0.4.5) (1.19.5)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.7/dist-packages (from mdsine2==0.4.5) (1.1.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from mdsine2==0.4.5) (1.4.1)
# Collecting matplotlib>=3.3.1
#   Downloading matplotlib-3.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 5.2 MB/s
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from mdsine2==0.4.5) (0.0)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from mdsine2==0.4.5) (0.11.2)
# Collecting h5py==2.9.0
#   Downloading h5py-2.9.0-cp37-cp37m-manylinux1_x86_64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 29.8 MB/s
# Collecting psutil==5.7.3
#   Downloading psutil-5.7.3.tar.gz (465 kB)
#      |████████████████████████████████| 465 kB 38.4 MB/s
# Collecting networkx==2.3
#   Downloading networkx-2.3.zip (1.7 MB)
#      |████████████████████████████████| 1.7 MB 22.8 MB/s
# Collecting numba==0.52
#   Downloading numba-0.52.0-cp37-cp37m-manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 45.5 MB/s
# Collecting biopython==1.78
#   Downloading biopython-1.78-cp37-cp37m-manylinux1_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 40.6 MB/s
# Collecting treeswift==1.1.14
#   Downloading treeswift-1.1.14-py2.py3-none-any.whl (32 kB)
# Collecting py2cytoscape==0.7.1
#   Downloading py2cytoscape-0.7.1.tar.gz (57 kB)
#      |████████████████████████████████| 57 kB 3.5 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from mdsine2==0.4.5) (4.62.3)
# Collecting PyQt5
#   Downloading PyQt5-5.15.6-cp36-abi3-manylinux1_x86_64.whl (8.3 MB)
#      |████████████████████████████████| 8.3 MB 39.5 MB/s
# Collecting ete3
#   Downloading ete3-3.1.2.tar.gz (4.7 MB)
#      |████████████████████████████████| 4.7 MB 32.3 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py==2.9.0->mdsine2==0.4.5) (1.15.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from networkx==2.3->mdsine2==0.4.5) (4.4.2)
# Collecting llvmlite<0.36,>=0.35.0
#   Downloading llvmlite-0.35.0-cp37-cp37m-manylinux2010_x86_64.whl (25.3 MB)
#      |████████████████████████████████| 25.3 MB 1.9 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba==0.52->mdsine2==0.4.5) (57.4.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.7/dist-packages (from py2cytoscape==0.7.1->mdsine2==0.4.5) (1.3.0)
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.7/dist-packages (from py2cytoscape==0.7.1->mdsine2==0.4.5) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from py2cytoscape==0.7.1->mdsine2==0.4.5) (2.23.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from py2cytoscape==0.7.1->mdsine2==0.4.5) (3.0.6)
# Collecting python-igraph
#   Downloading python-igraph-0.9.8.tar.gz (9.5 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.1->mdsine2==0.4.5) (7.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.1->mdsine2==0.4.5) (21.3)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.28.4-py3-none-any.whl (885 kB)
#      |████████████████████████████████| 885 kB 41.3 MB/s
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.1->mdsine2==0.4.5) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.1->mdsine2==0.4.5) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.1->mdsine2==0.4.5) (0.11.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->mdsine2==0.4.5) (2018.9)
# Collecting PyQt5-Qt5>=5.15.2
#   Downloading PyQt5_Qt5-5.15.2-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#      |████████████████████████████████| 59.9 MB 1.2 MB/s
# Collecting PyQt5-sip<13,>=12.8
#   Downloading PyQt5_sip-12.9.0-cp37-cp37m-manylinux1_x86_64.whl (317 kB)
#      |████████████████████████████████| 317 kB 35.6 MB/s
# Collecting igraph==0.9.8
#   Downloading igraph-0.9.8-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 46.4 MB/s
# Collecting texttable>=1.6.2
#   Downloading texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->py2cytoscape==0.7.1->mdsine2==0.4.5) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->py2cytoscape==0.7.1->mdsine2==0.4.5) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->py2cytoscape==0.7.1->mdsine2==0.4.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->py2cytoscape==0.7.1->mdsine2==0.4.5) (2.10)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->mdsine2==0.4.5) (1.0.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->mdsine2==0.4.5) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->mdsine2==0.4.5) (3.0.0)
# Building wheels for collected packages: mdsine2, networkx, psutil, py2cytoscape, ete3, python-igraph
#   Building wheel for mdsine2 (setup.py) ... done
#   Created wheel for mdsine2: filename=mdsine2-0.4.5-cp37-cp37m-linux_x86_64.whl size=331230 sha256=fe8360f2f5ee822b713cdb7f24bfbbb8ffd6838ab3cc91b3af2ec609882f7d5e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xmabsvnv/wheels/b7/19/91/a6396303d26cbb96faa55fdede89eb0dbe3c598d2306ddb8b8
#   Building wheel for networkx (setup.py) ... done
#   Created wheel for networkx: filename=networkx-2.3-py2.py3-none-any.whl size=1556009 sha256=16dd025f953358a7b867849e2aab1468120035f64617205b276c4bba360ceee8
#   Stored in directory: /root/.cache/pip/wheels/44/e6/b8/4efaab31158e9e9ca9ed80b11f6b11130bac9a9672b3cbbeaf
#   Building wheel for psutil (setup.py) ... done
#   Created wheel for psutil: filename=psutil-5.7.3-cp37-cp37m-linux_x86_64.whl size=285284 sha256=a233a7df4d1a41ade82de3e9414c336307ab8bb576845e4a755839b806786eee
#   Stored in directory: /root/.cache/pip/wheels/f0/4b/57/d037639271e326da3e80e0ddc37bd3d5da7bbf48b3173be557
#   Building wheel for py2cytoscape (setup.py) ... done
#   Created wheel for py2cytoscape: filename=py2cytoscape-0.7.1-py3-none-any.whl size=78829 sha256=3cfa6cf4103c1f9f35cb06a41fdcf759fcdf89a306dd68be6cf6b8ad5093187e
#   Stored in directory: /root/.cache/pip/wheels/17/d0/68/c5e4584aff90e7529b55fd9c7b8de97f4056ab615e91a65799
#   Building wheel for ete3 (setup.py) ... done
#   Created wheel for ete3: filename=ete3-3.1.2-py3-none-any.whl size=2273013 sha256=ce5dae93314ca5a85220235e496b44e6292f84a17396552d1d61bf8d4ab7afe7
#   Stored in directory: /root/.cache/pip/wheels/17/fd/e2/6ac384d8c2484789304657dde01b96d7ab83f4f1dd96d266df
#   Building wheel for python-igraph (setup.py) ... done
#   Created wheel for python-igraph: filename=python_igraph-0.9.8-py3-none-any.whl size=9070 sha256=c3252c5ce1392e8661c58ca21d6695b23dd6b586bef2058480808c3ee2e4d67d
#   Stored in directory: /root/.cache/pip/wheels/15/86/ef/b8bcdfbcb1c489771ad256c7cd1eb4971cdb7f3f670938b798
# Successfully built mdsine2 networkx psutil py2cytoscape ete3 python-igraph
# Installing collected packages: texttable, igraph, fonttools, python-igraph, PyQt5-sip, PyQt5-Qt5, networkx, matplotlib, llvmlite, treeswift, PyQt5, py2cytoscape, psutil, numba, h5py, ete3, biopython, mdsine2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.6.3
#     Uninstalling networkx-2.6.3:
#       Successfully uninstalled networkx-2.6.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.34.0
#     Uninstalling llvmlite-0.34.0:
#       Successfully uninstalled llvmlite-0.34.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: numba
#     Found existing installation: numba 0.51.2
#     Uninstalling numba-0.51.2:
#       Successfully uninstalled numba-0.51.2
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed PyQt5-5.15.6 PyQt5-Qt5-5.15.2 PyQt5-sip-12.9.0 biopython-1.78 ete3-3.1.2 fonttools-4.28.4 h5py-2.9.0 igraph-0.9.8 llvmlite-0.35.0 matplotlib-3.5.1 mdsine2-0.4.5 networkx-2.3 numba-0.52.0 psutil-5.7.3 py2cytoscape-0.7.1 python-igraph-0.9.8 texttable-1.6.4 treeswift-1.1.14

# %%
# !pip install wget
# !pip install zenodo-get
# !pip install scikit-bio
# !pip install tables==3.6.1 --force-reinstall
# Out:
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (3.2)
# Collecting zenodo-get
#   Downloading zenodo_get-1.3.4-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from zenodo-get) (2.23.0)
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (from zenodo-get) (3.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->zenodo-get) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->zenodo-get) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->zenodo-get) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->zenodo-get) (1.24.3)
# Installing collected packages: zenodo-get
# Successfully installed zenodo-get-1.3.4
# Collecting scikit-bio
#   Downloading scikit-bio-0.5.6.tar.gz (8.4 MB)
#      |████████████████████████████████| 8.4 MB 4.4 MB/s
# Collecting lockfile>=0.10.2
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: CacheControl>=0.11.5 in /usr/local/lib/python3.7/dist-packages (from scikit-bio) (0.12.10)
# Requirement already satisfied: decorator>=3.4.2 in /usr/local/lib/python3.7/dist-packages (from scikit-bio) (4.4.2)
# Requirement already satisfied: IPython>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from scikit-bio) (5.5.0)
# Requirement already satisfied: matplotlib>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from scikit-bio) (3.5.1)
# Requirement already satisfied: natsort>=4.0.3 in /usr/local/lib/python3.7/dist-packages (from scikit-bio) (5.5.0)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.7/dist-packages (from scikit-bio) (1.19.5)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-bio) (1.1.5)
# Requirement already satisfied: scipy>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-bio) (1.4.1)
# Collecting hdmedians>=0.13
#   Downloading hdmedians-0.14.2.tar.gz (7.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-bio) (1.0.1)
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from CacheControl>=0.11.5->scikit-bio) (1.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from CacheControl>=0.11.5->scikit-bio) (2.23.0)
# Requirement already satisfied: Cython>=0.23 in /usr/local/lib/python3.7/dist-packages (from hdmedians>=0.13->scikit-bio) (0.29.24)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython>=3.2.0->scikit-bio) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from IPython>=3.2.0->scikit-bio) (1.0.18)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from IPython>=3.2.0->scikit-bio) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython>=3.2.0->scikit-bio) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython>=3.2.0->scikit-bio) (5.1.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from IPython>=3.2.0->scikit-bio) (0.8.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython>=3.2.0->scikit-bio) (2.6.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.3->scikit-bio) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.3->scikit-bio) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.3->scikit-bio) (7.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.3->scikit-bio) (3.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.3->scikit-bio) (4.28.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.3->scikit-bio) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.3->scikit-bio) (0.11.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->scikit-bio) (2018.9)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython>=3.2.0->scikit-bio) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython>=3.2.0->scikit-bio) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.1->scikit-bio) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.1->scikit-bio) (1.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython>=3.2.0->scikit-bio) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->CacheControl>=0.11.5->scikit-bio) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->CacheControl>=0.11.5->scikit-bio) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->CacheControl>=0.11.5->scikit-bio) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->CacheControl>=0.11.5->scikit-bio) (2.10)
# Building wheels for collected packages: scikit-bio, hdmedians
#   Building wheel for scikit-bio (setup.py) ... done
#   Created wheel for scikit-bio: filename=scikit_bio-0.5.6-cp37-cp37m-linux_x86_64.whl size=1456885 sha256=235d3e8823fd4f427e817e8f85ef918f6ee7f78b9def81f5bad3beeb8107c319
#   Stored in directory: /root/.cache/pip/wheels/7e/fa/86/a8b3b3b1187f0b0997fca40cdb7dd0d81a57ff061010e4464d
#   Building wheel for hdmedians (PEP 517) ... done
#   Created wheel for hdmedians: filename=hdmedians-0.14.2-cp37-cp37m-linux_x86_64.whl size=453201 sha256=04e6e9ebc2f4d29dc6bc71ed416b7510e76d33a19af350ba287b5b9da1cf16f8
#   Stored in directory: /root/.cache/pip/wheels/56/5d/28/fb40426fbf6a8c3af88376a227130bbdf81e00177123e1398e
# Successfully built scikit-bio hdmedians
# Installing collected packages: lockfile, hdmedians, scikit-bio
# Successfully installed hdmedians-0.14.2 lockfile-0.12.2 scikit-bio-0.5.6
# Collecting tables==3.6.1
#   Downloading tables-3.6.1-cp37-cp37m-manylinux1_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 4.9 MB/s
# Collecting numexpr>=2.6.2
#   Downloading numexpr-2.8.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (379 kB)
#      |████████████████████████████████| 379 kB 1.8 MB/s
# Collecting numpy>=1.9.3
#   Downloading numpy-1.21.4-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 37.2 MB/s
# Collecting packaging
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.2 MB/s
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Downloading pyparsing-3.0.6-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 6.0 MB/s
# Installing collected packages: pyparsing, packaging, numpy, numexpr, tables
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.6
#     Uninstalling pyparsing-3.0.6:
#       Successfully uninstalled pyparsing-3.0.6
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: numexpr
#     Found existing installation: numexpr 2.7.3
#     Uninstalling numexpr-2.7.3:
#       Successfully uninstalled numexpr-2.7.3
#   Attempting uninstall: tables
#     Found existing installation: tables 3.4.4
#     Uninstalling tables-3.4.4:
#       Successfully uninstalled tables-3.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.21.4 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numexpr-2.8.1 numpy-1.21.4 packaging-21.3 pyparsing-3.0.6 tables-3.6.1

# %% [markdown]
# ### Zenodo file retrieval
#
# The relevant files needed to make the figures are saved in zenodo.

# %%
# !wget https://zenodo.org/record/5781391/files/forward_sims.tgz
# !wget https://zenodo.org/record/5781391/files/mixed_prior_fixed.tgz
# !wget https://zenodo.org/record/5781391/files/mixed_prior_unfixed.tgz
# !wget https://zenodo.org/record/5781848/files/other_files.tgz
# Out:
# --2021-12-15 18:20:22--  https://zenodo.org/record/5781391/files/forward_sims.tgz
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5183489132 (4.8G) [application/octet-stream]
# Saving to: ‘forward_sims.tgz’
#
# forward_sims.tgz    100%[===================>]   4.83G  5.62MB/s    in 6m 24s
#
# 2021-12-15 18:26:48 (12.9 MB/s) - ‘forward_sims.tgz’ saved [5183489132/5183489132]
#
# --2021-12-15 18:26:48--  https://zenodo.org/record/5781391/files/mixed_prior_fixed.tgz
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6286873326 (5.9G) [application/octet-stream]
# Saving to: ‘mixed_prior_fixed.tgz’
#
# mixed_prior_fixed.t 100%[===================>]   5.85G  6.06MB/s    in 7m 17s
#
# 2021-12-15 18:34:07 (13.7 MB/s) - ‘mixed_prior_fixed.tgz’ saved [6286873326/6286873326]
#
# --2021-12-15 18:34:07--  https://zenodo.org/record/5781391/files/mixed_prior_unfixed.tgz
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6246180525 (5.8G) [application/octet-stream]
# Saving to: ‘mixed_prior_unfixed.tgz’
#
# mixed_prior_unfixed 100%[===================>]   5.82G  6.96MB/s    in 8m 11s
#
# 2021-12-15 18:42:20 (12.1 MB/s) - ‘mixed_prior_unfixed.tgz’ saved [6246180525/6246180525]
#
# --2021-12-15 18:42:20--  https://zenodo.org/record/5781848/files/other_files.tgz
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 952125289 (908M) [application/octet-stream]
# Saving to: ‘other_files.tgz’
#
# other_files.tgz     100%[===================>] 908.02M  24.8MB/s    in 36s
#
# 2021-12-15 18:42:58 (25.1 MB/s) - ‘other_files.tgz’ saved [952125289/952125289]

# %%
#use if wget does not work
#!zenodo_get -d 10.5281/zenodo.5781391

# %%
#@title unzip the .tgz files
# !tar -xzvf "mixed_prior_fixed.tgz" 
# !tar -xzvf "mixed_prior_unfixed.tgz" 
# !tar -xzvf "forward_sims.tgz" 
# !tar -xzvf "other_files.tgz"
# Out:
# mixed_prior_fixed/
# mixed_prior_fixed/uc-seed0-mixed/
# mixed_prior_fixed/._.DS_Store
# mixed_prior_fixed/.DS_Store
# mixed_prior_fixed/healthy-seed0-mixed/
# mixed_prior_fixed/healthy-seed0-mixed/subjset.pkl
# mixed_prior_fixed/healthy-seed0-mixed/._.DS_Store
# mixed_prior_fixed/healthy-seed0-mixed/.DS_Store
# mixed_prior_fixed/healthy-seed0-mixed/metadata.txt
# mixed_prior_fixed/healthy-seed0-mixed/params.pkl
# mixed_prior_fixed/healthy-seed0-mixed/mcmc.pkl
# mixed_prior_fixed/healthy-seed0-mixed/traces.hdf5
# mixed_prior_fixed/uc-seed0-mixed/subjset.pkl
# mixed_prior_fixed/uc-seed0-mixed/._.DS_Store
# mixed_prior_fixed/uc-seed0-mixed/.DS_Store
# mixed_prior_fixed/uc-seed0-mixed/metadata.txt
# mixed_prior_fixed/uc-seed0-mixed/params.pkl
# mixed_prior_fixed/uc-seed0-mixed/mcmc.pkl
# mixed_prior_fixed/uc-seed0-mixed/traces.hdf5
# mixed_prior_unfixed/
# mixed_prior_unfixed/uc-seed0-mixed/
# mixed_prior_unfixed/._.DS_Store
# mixed_prior_unfixed/.DS_Store
# mixed_prior_unfixed/healthy-seed0-mixed/
# mixed_prior_unfixed/healthy-seed0-mixed/subjset.pkl
# mixed_prior_unfixed/healthy-seed0-mixed/._.DS_Store
# mixed_prior_unfixed/healthy-seed0-mixed/.DS_Store
# mixed_prior_unfixed/healthy-seed0-mixed/metadata.txt
# mixed_prior_unfixed/healthy-seed0-mixed/params.pkl
# mixed_prior_unfixed/healthy-seed0-mixed/mcmc.pkl
# mixed_prior_unfixed/healthy-seed0-mixed/traces.hdf5
# mixed_prior_unfixed/uc-seed0-mixed/subjset.pkl
# mixed_prior_unfixed/uc-seed0-mixed/._.DS_Store
# mixed_prior_unfixed/uc-seed0-mixed/.DS_Store
# mixed_prior_unfixed/uc-seed0-mixed/metadata.txt
# mixed_prior_unfixed/uc-seed0-mixed/params.pkl
# mixed_prior_unfixed/uc-seed0-mixed/mcmc.pkl
# mixed_prior_unfixed/uc-seed0-mixed/traces.hdf5
# forward_sims/
# forward_sims/healthy-cv5-validate-5-full-truth.npy
# forward_sims/uc-cv10-validate-10-full.npy
# forward_sims/healthy-cv4-validate-4-full.npy
# forward_sims/uc-cv8-validate-8-full-times.npy
# forward_sims/healthy-cv5-validate-5-full.npy
# forward_sims/._.DS_Store
# forward_sims/.DS_Store
# forward_sims/healthy-cv2-validate-2-full-truth.npy
# forward_sims/uc-cv10-validate-10-full-truth.npy
# forward_sims/uc-cv7-validate-7-full-times.npy
# forward_sims/healthy-cv4-validate-4-full-times.npy
# forward_sims/healthy-cv3-validate-3-full.npy
# forward_sims/healthy-cv2-validate-2-full.npy
# forward_sims/uc-cv9-validate-9-full-truth.npy
# forward_sims/uc-cv8-validate-8-full.npy
# forward_sims/uc-cv9-validate-9-full.npy
# forward_sims/healthy-cv3-validate-3-full-times.npy
# forward_sims/uc-cv6-validate-6-full-truth.npy
# forward_sims/healthy-cv5-validate-5-full-times.npy
# forward_sims/uc-cv8-validate-8-full-truth.npy
# forward_sims/healthy-cv2-validate-2-full-times.npy
# forward_sims/uc-cv7-validate-7-full-truth.npy
# forward_sims/uc-cv10-validate-10-full-times.npy
# forward_sims/uc-cv6-validate-6-full.npy
# forward_sims/healthy-cv4-validate-4-full-truth.npy
# forward_sims/uc-cv7-validate-7-full.npy
# forward_sims/uc-cv9-validate-9-full-times.npy
# forward_sims/healthy-cv3-validate-3-full-truth.npy
# forward_sims/uc-cv6-validate-6-full-times.npy
# ._output
# output/
# output/._gibson
# output/gibson/
# output/gibson/._processed_data_all
# output/gibson/processed_data_all/
# output/gibson/processed_data_all/._gibson_replicates_agg.fa
# output/gibson/processed_data_all/gibson_replicates_agg.fa
# output/gibson/processed_data_all/._gibson_healthy_agg.fa
# output/gibson/processed_data_all/gibson_healthy_agg.fa
# output/gibson/processed_data_all/._gibson_uc_agg.pkl
# output/gibson/processed_data_all/gibson_uc_agg.pkl
# output/gibson/processed_data_all/._gibson_healthy_agg_taxa.pkl
# output/gibson/processed_data_all/gibson_healthy_agg_taxa.pkl
# output/gibson/processed_data_all/._gibson_uc_agg_taxa_filtered.pkl
# output/gibson/processed_data_all/gibson_uc_agg_taxa_filtered.pkl
# output/gibson/processed_data_all/._gibson_inoculum_agg_taxa.pkl
# output/gibson/processed_data_all/gibson_inoculum_agg_taxa.pkl
# output/gibson/processed_data_all/._gibson_replicates_agg_taxa.pkl
# output/gibson/processed_data_all/gibson_replicates_agg_taxa.pkl
# output/gibson/processed_data_all/._gibson_uc_agg_taxa.pkl
# output/gibson/processed_data_all/gibson_uc_agg_taxa.pkl
# output/gibson/processed_data_all/._gibson_replicates_agg_taxa_filtered1.pkl
# output/gibson/processed_data_all/gibson_replicates_agg_taxa_filtered1.pkl
# output/gibson/processed_data_all/._gibson_healthy_agg.pkl
# output/gibson/processed_data_all/gibson_healthy_agg.pkl
# output/gibson/processed_data_all/._gibson_replicates_agg_taxa_filtered2.pkl
# output/gibson/processed_data_all/gibson_replicates_agg_taxa_filtered2.pkl
# output/gibson/processed_data_all/._gibson_uc_agg.fa
# output/gibson/processed_data_all/gibson_uc_agg.fa
# output/gibson/processed_data_all/._gibson_replicates_agg_taxa_filtered3.pkl
# output/gibson/processed_data_all/gibson_replicates_agg_taxa_filtered3.pkl
# output/gibson/processed_data_all/._gibson_healthy_agg_taxa_filtered.pkl
# output/gibson/processed_data_all/gibson_healthy_agg_taxa_filtered.pkl
# output/gibson/processed_data_all/._gibson_uc_agg_taxa_filtered2.pkl
# output/gibson/processed_data_all/gibson_uc_agg_taxa_filtered2.pkl
# output/gibson/processed_data_all/._gibson_uc_agg_taxa_filtered3.pkl
# output/gibson/processed_data_all/gibson_uc_agg_taxa_filtered3.pkl
# output/gibson/processed_data_all/._gibson_healthy_agg_taxa_filtered1.pkl
# output/gibson/processed_data_all/gibson_healthy_agg_taxa_filtered1.pkl
# output/gibson/processed_data_all/._gibson_healthy_agg_taxa_filtered3.pkl
# output/gibson/processed_data_all/gibson_healthy_agg_taxa_filtered3.pkl
# output/gibson/processed_data_all/._gibson_uc_agg_taxa_filtered1.pkl
# output/gibson/processed_data_all/gibson_uc_agg_taxa_filtered1.pkl
# output/gibson/processed_data_all/._gibson_healthy_agg_taxa_filtered2.pkl
# output/gibson/processed_data_all/gibson_healthy_agg_taxa_filtered2.pkl
# output/gibson/processed_data_all/._gibson_replicates_agg.pkl
# output/gibson/processed_data_all/gibson_replicates_agg.pkl
# output/gibson/processed_data_all/._gibson_replicates_agg_taxa_filtered.pkl
# output/gibson/processed_data_all/gibson_replicates_agg_taxa_filtered.pkl
# output/gibson/processed_data_all/._gibson_inoculum_agg.fa
# output/gibson/processed_data_all/gibson_inoculum_agg.fa
# output/gibson/processed_data_all/._gibson_inoculum_agg.pkl
# output/gibson/processed_data_all/gibson_inoculum_agg.pkl
# eigenvalues/
# eigenvalues/seed1-strong-sparse/
# eigenvalues/._.DS_Store
# tar: Ignoring unknown extended header keyword 'SCHILY.fflags'
# eigenvalues/.DS_Store
# eigenvalues/seed0-mixed-fixed/
# eigenvalues/seed0-strong-sparse/
# eigenvalues/seed0-mixed4/
# eigenvalues/seed0-mixed/
# eigenvalues/seed0-mixed/eigenvalues.npz
# eigenvalues/seed0-mixed4/eigenvalues.npz
# eigenvalues/seed0-strong-sparse/eigenvalues.npz
# eigenvalues/seed0-mixed-fixed/eigenvalues.npz
# eigenvalues/seed1-strong-sparse/eigenvalues.npz
# keystoneness/
# keystoneness/healthy_fwsim_day20.h5
# keystoneness/uc_fwsim_day20.h5
# fwsim_random_pert/
# fwsim_random_pert/uc_metadata.h5
# fwsim_random_pert/healthy_metadata.h5
# fwsim_random_pert/healthy_fwsim.h5
# fwsim_random_pert/uc_fwsim.h5
# ._clv_results
# clv_results/
# clv_results/._results_abs_ridge
# clv_results/results_abs_ridge/
# clv_results/._results_abs_elastic
# clv_results/results_abs_elastic/
# clv_results/._.DS_Store
# clv_results/.DS_Store
# clv_results/._results_rel_elastic
# clv_results/results_rel_elastic/
# clv_results/._results_rel_ridge
# clv_results/results_rel_ridge/
# clv_results/results_rel_ridge/._gibson_uc_predictions-1-glv-model.pkl
# clv_results/results_rel_ridge/gibson_uc_predictions-1-glv-model.pkl
# clv_results/results_rel_ridge/._.DS_Store
# clv_results/results_rel_ridge/.DS_Store
# clv_results/results_rel_ridge/._gibson_uc_predictions-2-glv-model.pkl
# clv_results/results_rel_ridge/gibson_uc_predictions-2-glv-model.pkl
# clv_results/results_rel_ridge/._forward_sims_rel_ridge.zip
# clv_results/results_rel_ridge/forward_sims_rel_ridge.zip
# clv_results/results_rel_ridge/._gibson_healthy_predictions-0-glv-model.pkl
# clv_results/results_rel_ridge/gibson_healthy_predictions-0-glv-model.pkl
# clv_results/results_rel_ridge/._old
# clv_results/results_rel_ridge/old/
# clv_results/results_rel_ridge/._gibson_healthy_predictions-3-glv-model.pkl
# clv_results/results_rel_ridge/gibson_healthy_predictions-3-glv-model.pkl
# clv_results/results_rel_ridge/._gibson_healthy_predictions-2-glv-model.pkl
# clv_results/results_rel_ridge/gibson_healthy_predictions-2-glv-model.pkl
# clv_results/results_rel_ridge/._gibson_healthy_predictions-1-glv-model.pkl
# clv_results/results_rel_ridge/gibson_healthy_predictions-1-glv-model.pkl
# clv_results/results_rel_ridge/._gibson_uc_predictions-2-glv
# clv_results/results_rel_ridge/gibson_uc_predictions-2-glv
# clv_results/results_rel_ridge/._gibson_uc_predictions-3-glv
# clv_results/results_rel_ridge/gibson_uc_predictions-3-glv
# clv_results/results_rel_ridge/._gibson_uc_predictions-1-glv
# clv_results/results_rel_ridge/gibson_uc_predictions-1-glv
# clv_results/results_rel_ridge/._gibson_uc_predictions-3-glv-model.pkl
# clv_results/results_rel_ridge/gibson_uc_predictions-3-glv-model.pkl
# clv_results/results_rel_ridge/._gibson_uc_predictions-0-glv
# clv_results/results_rel_ridge/gibson_uc_predictions-0-glv
# clv_results/results_rel_ridge/._gibson_uc_predictions-4-glv-model.pkl
# clv_results/results_rel_ridge/gibson_uc_predictions-4-glv-model.pkl
# clv_results/results_rel_ridge/._gibson_uc_predictions-4-glv
# clv_results/results_rel_ridge/gibson_uc_predictions-4-glv
# clv_results/results_rel_ridge/._gibson_healthy_predictions-3-glv
# clv_results/results_rel_ridge/gibson_healthy_predictions-3-glv
# clv_results/results_rel_ridge/._gibson_healthy_predictions-2-glv
# clv_results/results_rel_ridge/gibson_healthy_predictions-2-glv
# clv_results/results_rel_ridge/._gibson_uc_predictions-0-glv-model.pkl
# clv_results/results_rel_ridge/gibson_uc_predictions-0-glv-model.pkl
# clv_results/results_rel_ridge/._gibson_healthy_predictions-0-glv
# clv_results/results_rel_ridge/gibson_healthy_predictions-0-glv
# clv_results/results_rel_ridge/._gibson_healthy_predictions-1-glv
# clv_results/results_rel_ridge/gibson_healthy_predictions-1-glv
# clv_results/results_rel_ridge/old/._gibson_uc_predictions-1-glv-model.pkl
# clv_results/results_rel_ridge/old/gibson_uc_predictions-1-glv-model.pkl
# clv_results/results_rel_ridge/old/._gibson_uc_predictions-2-glv-model.pkl
# clv_results/results_rel_ridge/old/gibson_uc_predictions-2-glv-model.pkl
# clv_results/results_rel_ridge/old/._gibson_healthy_predictions-0-glv-model.pkl
# clv_results/results_rel_ridge/old/gibson_healthy_predictions-0-glv-model.pkl
# clv_results/results_rel_ridge/old/._gibson_healthy_predictions-3-glv-model.pkl
# clv_results/results_rel_ridge/old/gibson_healthy_predictions-3-glv-model.pkl
# clv_results/results_rel_ridge/old/._gibson_healthy_predictions-2-glv-model.pkl
# clv_results/results_rel_ridge/old/gibson_healthy_predictions-2-glv-model.pkl
# clv_results/results_rel_ridge/old/._gibson_healthy_predictions-1-glv-model.pkl
# clv_results/results_rel_ridge/old/gibson_healthy_predictions-1-glv-model.pkl
# clv_results/results_rel_ridge/old/._gibson_uc_predictions-2-glv
# clv_results/results_rel_ridge/old/gibson_uc_predictions-2-glv
# clv_results/results_rel_ridge/old/._gibson_uc_predictions-3-glv
# clv_results/results_rel_ridge/old/gibson_uc_predictions-3-glv
# clv_results/results_rel_ridge/old/._gibson_uc_predictions-1-glv
# clv_results/results_rel_ridge/old/gibson_uc_predictions-1-glv
# clv_results/results_rel_ridge/old/._gibson_uc_predictions-3-glv-model.pkl
# clv_results/results_rel_ridge/old/gibson_uc_predictions-3-glv-model.pkl
# clv_results/results_rel_ridge/old/._gibson_uc_predictions-0-glv
# clv_results/results_rel_ridge/old/gibson_uc_predictions-0-glv
# clv_results/results_rel_ridge/old/._gibson_uc_predictions-4-glv-model.pkl
# clv_results/results_rel_ridge/old/gibson_uc_predictions-4-glv-model.pkl
# clv_results/results_rel_ridge/old/._gibson_uc_predictions-4-glv
# clv_results/results_rel_ridge/old/gibson_uc_predictions-4-glv
# clv_results/results_rel_ridge/old/._gibson_healthy_predictions-3-glv
# clv_results/results_rel_ridge/old/gibson_healthy_predictions-3-glv
# clv_results/results_rel_ridge/old/._gibson_healthy_predictions-2-glv
# clv_results/results_rel_ridge/old/gibson_healthy_predictions-2-glv
# clv_results/results_rel_ridge/old/._gibson_uc_predictions-0-glv-model.pkl
# clv_results/results_rel_ridge/old/gibson_uc_predictions-0-glv-model.pkl
# clv_results/results_rel_ridge/old/._gibson_healthy_predictions-0-glv
# clv_results/results_rel_ridge/old/gibson_healthy_predictions-0-glv
# clv_results/results_rel_ridge/old/._gibson_healthy_predictions-1-glv
# clv_results/results_rel_ridge/old/gibson_healthy_predictions-1-glv
# clv_results/results_rel_elastic/._gibson_uc_predictions-1-glv-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-1-glv-model.pkl
# clv_results/results_rel_elastic/._gibson_healthy_predictions-0-lra
# clv_results/results_rel_elastic/gibson_healthy_predictions-0-lra
# clv_results/results_rel_elastic/._gibson_healthy_predictions-0-lra-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-0-lra-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-2-glv-ra-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-2-glv-ra-model.pkl
# clv_results/results_rel_elastic/._gibson_healthy_predictions-2-glv-ra-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-2-glv-ra-model.pkl
# clv_results/results_rel_elastic/._gibson_healthy_predictions-1-lra
# clv_results/results_rel_elastic/gibson_healthy_predictions-1-lra
# clv_results/results_rel_elastic/._gibson_healthy_predictions-2-clv-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-2-clv-model.pkl
# clv_results/results_rel_elastic/._gibson_healthy_predictions-3-lra
# clv_results/results_rel_elastic/gibson_healthy_predictions-3-lra
# clv_results/results_rel_elastic/._gibson_healthy_predictions-1-glv-ra
# clv_results/results_rel_elastic/gibson_healthy_predictions-1-glv-ra
# clv_results/results_rel_elastic/._gibson_uc_predictions-4-lra
# clv_results/results_rel_elastic/gibson_uc_predictions-4-lra
# clv_results/results_rel_elastic/._forward_sims_rel_elastic.zip
# clv_results/results_rel_elastic/forward_sims_rel_elastic.zip
# clv_results/results_rel_elastic/._gibson_healthy_predictions-2-lra
# clv_results/results_rel_elastic/gibson_healthy_predictions-2-lra
# clv_results/results_rel_elastic/._gibson_healthy_predictions-3-glv-ra
# clv_results/results_rel_elastic/gibson_healthy_predictions-3-glv-ra
# clv_results/results_rel_elastic/._.DS_Store
# clv_results/results_rel_elastic/.DS_Store
# clv_results/results_rel_elastic/._gibson_uc_predictions-1-lra
# clv_results/results_rel_elastic/gibson_uc_predictions-1-lra
# clv_results/results_rel_elastic/._gibson_uc_predictions-0-lra
# clv_results/results_rel_elastic/gibson_uc_predictions-0-lra
# clv_results/results_rel_elastic/._gibson_healthy_predictions-3-lra-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-3-lra-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-2-lra
# clv_results/results_rel_elastic/gibson_uc_predictions-2-lra
# clv_results/results_rel_elastic/._gibson_uc_predictions-2-glv-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-2-glv-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-3-lra
# clv_results/results_rel_elastic/gibson_uc_predictions-3-lra
# clv_results/results_rel_elastic/._gibson_healthy_predictions-1-clv-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-1-clv-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-1-glv-ra
# clv_results/results_rel_elastic/gibson_uc_predictions-1-glv-ra
# clv_results/results_rel_elastic/._gibson_healthy_predictions-3-glv-ra-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-3-glv-ra-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-3-glv-ra-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-3-glv-ra-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-3-clv-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-3-clv-model.pkl
# clv_results/results_rel_elastic/._gibson_healthy_predictions-0-glv-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-0-glv-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-1-lra-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-1-lra-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-0-clv-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-0-clv-model.pkl
# clv_results/results_rel_elastic/._old
# clv_results/results_rel_elastic/old/
# clv_results/results_rel_elastic/._gibson_uc_predictions-4-clv-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-4-clv-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-2-lra-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-2-lra-model.pkl
# clv_results/results_rel_elastic/._gibson_healthy_predictions-3-glv-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-3-glv-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-3-glv-ra
# clv_results/results_rel_elastic/gibson_uc_predictions-3-glv-ra
# clv_results/results_rel_elastic/._gibson_healthy_predictions-2-glv-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-2-glv-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-3-lra-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-3-lra-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-1-clv-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-1-clv-model.pkl
# clv_results/results_rel_elastic/._gibson_healthy_predictions-0-glv-ra
# clv_results/results_rel_elastic/gibson_healthy_predictions-0-glv-ra
# clv_results/results_rel_elastic/._gibson_healthy_predictions-0-glv-ra-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-0-glv-ra-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-0-glv-ra-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-0-glv-ra-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-4-glv-ra-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-4-glv-ra-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-0-lra-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-0-lra-model.pkl
# clv_results/results_rel_elastic/._gibson_healthy_predictions-1-glv-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-1-glv-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-4-glv-ra
# clv_results/results_rel_elastic/gibson_uc_predictions-4-glv-ra
# clv_results/results_rel_elastic/._gibson_healthy_predictions-2-glv-ra
# clv_results/results_rel_elastic/gibson_healthy_predictions-2-glv-ra
# clv_results/results_rel_elastic/._gibson_uc_predictions-4-lra-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-4-lra-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-2-clv-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-2-clv-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-2-glv
# clv_results/results_rel_elastic/gibson_uc_predictions-2-glv
# clv_results/results_rel_elastic/._gibson_uc_predictions-0-clv
# clv_results/results_rel_elastic/gibson_uc_predictions-0-clv
# clv_results/results_rel_elastic/._gibson_uc_predictions-1-clv
# clv_results/results_rel_elastic/gibson_uc_predictions-1-clv
# clv_results/results_rel_elastic/._gibson_uc_predictions-3-glv
# clv_results/results_rel_elastic/gibson_uc_predictions-3-glv
# clv_results/results_rel_elastic/._gibson_healthy_predictions-0-clv-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-0-clv-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-1-glv
# clv_results/results_rel_elastic/gibson_uc_predictions-1-glv
# clv_results/results_rel_elastic/._gibson_uc_predictions-3-clv
# clv_results/results_rel_elastic/gibson_uc_predictions-3-clv
# clv_results/results_rel_elastic/._gibson_uc_predictions-2-clv
# clv_results/results_rel_elastic/gibson_uc_predictions-2-clv
# clv_results/results_rel_elastic/._gibson_uc_predictions-3-glv-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-3-glv-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-0-glv-ra
# clv_results/results_rel_elastic/gibson_uc_predictions-0-glv-ra
# clv_results/results_rel_elastic/._gibson_healthy_predictions-2-lra-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-2-lra-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-0-glv
# clv_results/results_rel_elastic/gibson_uc_predictions-0-glv
# clv_results/results_rel_elastic/._gibson_uc_predictions-1-glv-ra-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-1-glv-ra-model.pkl
# clv_results/results_rel_elastic/._gibson_healthy_predictions-1-glv-ra-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-1-glv-ra-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-4-glv-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-4-glv-model.pkl
# clv_results/results_rel_elastic/._gibson_healthy_predictions-3-clv-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-3-clv-model.pkl
# clv_results/results_rel_elastic/._gibson_healthy_predictions-1-clv
# clv_results/results_rel_elastic/gibson_healthy_predictions-1-clv
# clv_results/results_rel_elastic/._gibson_uc_predictions-4-glv
# clv_results/results_rel_elastic/gibson_uc_predictions-4-glv
# clv_results/results_rel_elastic/._gibson_healthy_predictions-3-glv
# clv_results/results_rel_elastic/gibson_healthy_predictions-3-glv
# clv_results/results_rel_elastic/._gibson_healthy_predictions-2-glv
# clv_results/results_rel_elastic/gibson_healthy_predictions-2-glv
# clv_results/results_rel_elastic/._gibson_healthy_predictions-1-lra-model.pkl
# clv_results/results_rel_elastic/gibson_healthy_predictions-1-lra-model.pkl
# clv_results/results_rel_elastic/._gibson_uc_predictions-0-glv-model.pkl
# clv_results/results_rel_elastic/gibson_uc_predictions-0-glv-model.pkl
# clv_results/results_rel_elastic/._gibson_healthy_predictions-0-clv
# clv_results/results_rel_elastic/gibson_healthy_predictions-0-clv
# clv_results/results_rel_elastic/._gibson_uc_predictions-2-glv-ra
# clv_results/results_rel_elastic/gibson_uc_predictions-2-glv-ra
# clv_results/results_rel_elastic/._gibson_healthy_predictions-2-clv
# clv_results/results_rel_elastic/gibson_healthy_predictions-2-clv
# clv_results/results_rel_elastic/._gibson_healthy_predictions-0-glv
# clv_results/results_rel_elastic/gibson_healthy_predictions-0-glv
# clv_results/results_rel_elastic/._gibson_uc_predictions-4-clv
# clv_results/results_rel_elastic/gibson_uc_predictions-4-clv
# clv_results/results_rel_elastic/._gibson_healthy_predictions-1-glv
# clv_results/results_rel_elastic/gibson_healthy_predictions-1-glv
# clv_results/results_rel_elastic/._gibson_healthy_predictions-3-clv
# clv_results/results_rel_elastic/gibson_healthy_predictions-3-clv
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-1-glv-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-1-glv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-0-lra
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-0-lra
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-0-lra-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-0-lra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-2-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-2-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-2-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-2-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-1-lra
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-1-lra
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-2-clv-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-2-clv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-3-lra
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-3-lra
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-1-glv-ra
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-1-glv-ra
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-4-lra
# clv_results/results_rel_elastic/old/gibson_uc_predictions-4-lra
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-2-lra
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-2-lra
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-3-glv-ra
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-3-glv-ra
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-1-lra
# clv_results/results_rel_elastic/old/gibson_uc_predictions-1-lra
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-0-lra
# clv_results/results_rel_elastic/old/gibson_uc_predictions-0-lra
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-3-lra-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-3-lra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-2-lra
# clv_results/results_rel_elastic/old/gibson_uc_predictions-2-lra
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-2-glv-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-2-glv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-3-lra
# clv_results/results_rel_elastic/old/gibson_uc_predictions-3-lra
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-1-clv-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-1-clv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-1-glv-ra
# clv_results/results_rel_elastic/old/gibson_uc_predictions-1-glv-ra
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-3-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-3-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-3-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-3-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-3-clv-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-3-clv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-0-glv-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-0-glv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-1-lra-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-1-lra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-0-clv-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-0-clv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-4-clv-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-4-clv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-2-lra-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-2-lra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-3-glv-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-3-glv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-3-glv-ra
# clv_results/results_rel_elastic/old/gibson_uc_predictions-3-glv-ra
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-2-glv-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-2-glv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-3-lra-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-3-lra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-1-clv-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-1-clv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-0-glv-ra
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-0-glv-ra
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-0-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-0-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-0-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-0-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-4-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-4-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-0-lra-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-0-lra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-1-glv-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-1-glv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-4-glv-ra
# clv_results/results_rel_elastic/old/gibson_uc_predictions-4-glv-ra
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-2-glv-ra
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-2-glv-ra
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-4-lra-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-4-lra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-2-clv-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-2-clv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-2-glv
# clv_results/results_rel_elastic/old/gibson_uc_predictions-2-glv
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-0-clv
# clv_results/results_rel_elastic/old/gibson_uc_predictions-0-clv
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-1-clv
# clv_results/results_rel_elastic/old/gibson_uc_predictions-1-clv
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-3-glv
# clv_results/results_rel_elastic/old/gibson_uc_predictions-3-glv
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-0-clv-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-0-clv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-1-glv
# clv_results/results_rel_elastic/old/gibson_uc_predictions-1-glv
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-3-clv
# clv_results/results_rel_elastic/old/gibson_uc_predictions-3-clv
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-2-clv
# clv_results/results_rel_elastic/old/gibson_uc_predictions-2-clv
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-3-glv-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-3-glv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-0-glv-ra
# clv_results/results_rel_elastic/old/gibson_uc_predictions-0-glv-ra
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-2-lra-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-2-lra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-0-glv
# clv_results/results_rel_elastic/old/gibson_uc_predictions-0-glv
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-1-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-1-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-1-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-1-glv-ra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-4-glv-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-4-glv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-3-clv-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-3-clv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-1-clv
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-1-clv
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-4-glv
# clv_results/results_rel_elastic/old/gibson_uc_predictions-4-glv
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-3-glv
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-3-glv
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-2-glv
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-2-glv
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-1-lra-model.pkl
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-1-lra-model.pkl
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-0-glv-model.pkl
# clv_results/results_rel_elastic/old/gibson_uc_predictions-0-glv-model.pkl
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-0-clv
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-0-clv
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-2-glv-ra
# clv_results/results_rel_elastic/old/gibson_uc_predictions-2-glv-ra
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-2-clv
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-2-clv
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-0-glv
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-0-glv
# clv_results/results_rel_elastic/old/._gibson_uc_predictions-4-clv
# clv_results/results_rel_elastic/old/gibson_uc_predictions-4-clv
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-1-glv
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-1-glv
# clv_results/results_rel_elastic/old/._gibson_healthy_predictions-3-clv
# clv_results/results_rel_elastic/old/gibson_healthy_predictions-3-clv
# clv_results/results_abs_elastic/._gibson_uc_predictions-3-glv-abs
# clv_results/results_abs_elastic/gibson_uc_predictions-3-glv-abs
# clv_results/results_abs_elastic/._gibson_uc_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_elastic/gibson_uc_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_elastic/._gibson_uc_predictions-2-glv-abs
# clv_results/results_abs_elastic/gibson_uc_predictions-2-glv-abs
# clv_results/results_abs_elastic/._.DS_Store
# clv_results/results_abs_elastic/.DS_Store
# clv_results/results_abs_elastic/._gibson_uc_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_elastic/gibson_uc_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_elastic/._gibson_uc_predictions-0-glv-abs
# clv_results/results_abs_elastic/gibson_uc_predictions-0-glv-abs
# clv_results/results_abs_elastic/._gibson_uc_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_elastic/gibson_uc_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_elastic/._gibson_uc_predictions-4-glv-abs-model.pkl
# clv_results/results_abs_elastic/gibson_uc_predictions-4-glv-abs-model.pkl
# clv_results/results_abs_elastic/._old
# clv_results/results_abs_elastic/old/
# clv_results/results_abs_elastic/._gibson_uc_predictions-1-glv-abs
# clv_results/results_abs_elastic/gibson_uc_predictions-1-glv-abs
# clv_results/results_abs_elastic/._gibson_uc_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_elastic/gibson_uc_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_elastic/._gibson_healthy_predictions-1-glv-abs
# clv_results/results_abs_elastic/gibson_healthy_predictions-1-glv-abs
# clv_results/results_abs_elastic/._gibson_uc_predictions-4-glv-abs
# clv_results/results_abs_elastic/gibson_uc_predictions-4-glv-abs
# clv_results/results_abs_elastic/._gibson_healthy_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_elastic/gibson_healthy_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_elastic/._gibson_healthy_predictions-0-glv-abs
# clv_results/results_abs_elastic/gibson_healthy_predictions-0-glv-abs
# clv_results/results_abs_elastic/._gibson_healthy_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_elastic/gibson_healthy_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_elastic/._gibson_healthy_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_elastic/gibson_healthy_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_elastic/._gibson_healthy_predictions-2-glv-abs
# clv_results/results_abs_elastic/gibson_healthy_predictions-2-glv-abs
# clv_results/results_abs_elastic/._forward_sims_abs_elastic.zip
# clv_results/results_abs_elastic/forward_sims_abs_elastic.zip
# clv_results/results_abs_elastic/._gibson_healthy_predictions-3-glv-abs
# clv_results/results_abs_elastic/gibson_healthy_predictions-3-glv-abs
# clv_results/results_abs_elastic/._gibson_healthy_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_elastic/gibson_healthy_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/._gibson_uc_predictions-3-glv-abs
# clv_results/results_abs_elastic/old/gibson_uc_predictions-3-glv-abs
# clv_results/results_abs_elastic/old/._gibson_uc_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/gibson_uc_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/._gibson_uc_predictions-2-glv-abs
# clv_results/results_abs_elastic/old/gibson_uc_predictions-2-glv-abs
# clv_results/results_abs_elastic/old/._gibson_uc_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/gibson_uc_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/._gibson_uc_predictions-0-glv-abs
# clv_results/results_abs_elastic/old/gibson_uc_predictions-0-glv-abs
# clv_results/results_abs_elastic/old/._gibson_uc_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/gibson_uc_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/._gibson_uc_predictions-4-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/gibson_uc_predictions-4-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/._gibson_uc_predictions-1-glv-abs
# clv_results/results_abs_elastic/old/gibson_uc_predictions-1-glv-abs
# clv_results/results_abs_elastic/old/._gibson_uc_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/gibson_uc_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/._gibson_healthy_predictions-1-glv-abs
# clv_results/results_abs_elastic/old/gibson_healthy_predictions-1-glv-abs
# clv_results/results_abs_elastic/old/._gibson_uc_predictions-4-glv-abs
# clv_results/results_abs_elastic/old/gibson_uc_predictions-4-glv-abs
# clv_results/results_abs_elastic/old/._gibson_healthy_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/gibson_healthy_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/._gibson_healthy_predictions-0-glv-abs
# clv_results/results_abs_elastic/old/gibson_healthy_predictions-0-glv-abs
# clv_results/results_abs_elastic/old/._gibson_healthy_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/gibson_healthy_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/._gibson_healthy_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/gibson_healthy_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/._gibson_healthy_predictions-2-glv-abs
# clv_results/results_abs_elastic/old/gibson_healthy_predictions-2-glv-abs
# clv_results/results_abs_elastic/old/._gibson_healthy_predictions-3-glv-abs
# clv_results/results_abs_elastic/old/gibson_healthy_predictions-3-glv-abs
# clv_results/results_abs_elastic/old/._gibson_healthy_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_elastic/old/gibson_healthy_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_ridge/._.DS_Store
# clv_results/results_abs_ridge/.DS_Store
# clv_results/results_abs_ridge/._forward_sims_abs_ridge
# clv_results/results_abs_ridge/forward_sims_abs_ridge/
# clv_results/results_abs_ridge/._old
# clv_results/results_abs_ridge/old/
# clv_results/results_abs_ridge/old/._gibson_uc_predictions-3-glv-abs
# clv_results/results_abs_ridge/old/gibson_uc_predictions-3-glv-abs
# clv_results/results_abs_ridge/old/._gibson_uc_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/gibson_uc_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/._gibson_uc_predictions-2-glv-abs
# clv_results/results_abs_ridge/old/gibson_uc_predictions-2-glv-abs
# clv_results/results_abs_ridge/old/._gibson_uc_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/gibson_uc_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/._gibson_uc_predictions-0-glv-abs
# clv_results/results_abs_ridge/old/gibson_uc_predictions-0-glv-abs
# clv_results/results_abs_ridge/old/._gibson_uc_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/gibson_uc_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/._gibson_uc_predictions-4-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/gibson_uc_predictions-4-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/._gibson_uc_predictions-1-glv-abs
# clv_results/results_abs_ridge/old/gibson_uc_predictions-1-glv-abs
# clv_results/results_abs_ridge/old/._gibson_uc_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/gibson_uc_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/._gibson_healthy_predictions-1-glv-abs
# clv_results/results_abs_ridge/old/gibson_healthy_predictions-1-glv-abs
# clv_results/results_abs_ridge/old/._gibson_uc_predictions-4-glv-abs
# clv_results/results_abs_ridge/old/gibson_uc_predictions-4-glv-abs
# clv_results/results_abs_ridge/old/._gibson_healthy_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/gibson_healthy_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/._gibson_healthy_predictions-0-glv-abs
# clv_results/results_abs_ridge/old/gibson_healthy_predictions-0-glv-abs
# clv_results/results_abs_ridge/old/._gibson_healthy_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/gibson_healthy_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/._gibson_healthy_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/gibson_healthy_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/._gibson_healthy_predictions-2-glv-abs
# clv_results/results_abs_ridge/old/gibson_healthy_predictions-2-glv-abs
# clv_results/results_abs_ridge/old/._gibson_healthy_predictions-3-glv-abs
# clv_results/results_abs_ridge/old/gibson_healthy_predictions-3-glv-abs
# clv_results/results_abs_ridge/old/._gibson_healthy_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_ridge/old/gibson_healthy_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_uc_predictions-3-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_uc_predictions-3-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_uc_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_uc_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_uc_predictions-2-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_uc_predictions-2-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_uc_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_uc_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_uc_predictions-0-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_uc_predictions-0-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_uc_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_uc_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_uc_predictions-4-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_uc_predictions-4-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_uc_predictions-1-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_uc_predictions-1-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._forward_sims_abs_ridge.zip
# clv_results/results_abs_ridge/forward_sims_abs_ridge/forward_sims_abs_ridge.zip
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_uc_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_uc_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_healthy_predictions-1-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_healthy_predictions-1-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_uc_predictions-4-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_uc_predictions-4-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_healthy_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_healthy_predictions-2-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_healthy_predictions-0-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_healthy_predictions-0-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_healthy_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_healthy_predictions-3-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_healthy_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_healthy_predictions-0-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_healthy_predictions-2-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_healthy_predictions-2-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_healthy_predictions-3-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_healthy_predictions-3-glv-abs
# clv_results/results_abs_ridge/forward_sims_abs_ridge/._gibson_healthy_predictions-1-glv-abs-model.pkl
# clv_results/results_abs_ridge/forward_sims_abs_ridge/gibson_healthy_predictions-1-glv-abs-model.pkl
# ._coarsening
# coarsening/
# coarsening/._pna_arithmetic_mean.jpg
# coarsening/pna_arithmetic_mean.jpg
# coarsening/._sanity_test.txt
# coarsening/sanity_test.txt
# coarsening/._arithmetic_mean_data.csv
# coarsening/arithmetic_mean_data.csv
# coarsening/._distance.csv
# coarsening/distance.csv
# coarsening/._arithmetic_mean_null_all.csv
# coarsening/arithmetic_mean_null_all.csv

# %%
# !git clone --branch sawal_final_changes https://github.com/gerberlab/MDSINE2_Paper
# Out:
# Cloning into 'MDSINE2_Paper'...
# remote: Enumerating objects: 3486, done.
# remote: Counting objects: 100% (1058/1058), done.
# remote: Compressing objects: 100% (722/722), done.
# remote: Total 3486 (delta 657), reused 676 (delta 327), pack-reused 2428
# Receiving objects: 100% (3486/3486), 87.39 MiB | 13.94 MiB/s, done.
# Resolving deltas: 100% (2197/2197), done.

# %%
# %cd /content/MDSINE2_Paper/analysis/
# %pwd
# %matplotlib notebook
import matplotlib.pyplot as plt 
from pathlib import Path
import os

saveloc = "gibson_inference/figures/output_figures"
os.makedirs(saveloc, exist_ok=True)
# Out:
# /content/MDSINE2_Paper/analysis

# %% [markdown]
# ## Figure 2
#
# The figure is made in two steps. First, we plot all the parts but the heatmap showing deseq results. Also, the animations in panel A of the figure are not visible. They are added manually using Adobe Illustrator.

# %%
# !python gibson_inference/figures/figure2.py \
       -file1 "gibson_inference/figures/preprocessed_all/gibson_healthy_agg_taxa.pkl" \
       -file2 "gibson_inference/figures/preprocessed_all/gibson_uc_agg_taxa.pkl" \
       -file3 "gibson_inference/figures/preprocessed_all/gibson_inoculum_agg_taxa.pkl"
# Out:
# Making Figure 2
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# Done Making Figure 2

# %% [markdown]
# ##Figure 2 Heatmap
#
# The output files are called mat_order_high_ss and mat_order_low_ss; the former and latter files illustrate the deseq results for order/family whose relative abundances are >0.5 and <0.5% respectively. The heatmaps are compiled into the paper version manually using Adobe Illustrator.

# %%
# !python gibson_inference/figures/deseq_heatmap_ss.py \
    -loc "gibson_inference/figures/figure2_files" \
    -abund "high" \
    -txt "abundant_species" \
    -taxo "order" \
    -o "mat_order_high_ss" \
    -o_loc "gibson_inference/figures/output_figures"


# !python gibson_inference/figures/deseq_heatmap_ss.py \
    -loc "gibson_inference/figures/figure2_files" \
    -abund "low" \
    -txt "abundant_species" \
    -taxo "order" \
    -o "mat_order_low_ss" \
    -o_loc "gibson_inference/figures/output_figures"
# Out:
# Making Heatmap for species with abundance > 0.5%
# Done making heatmaps
# Making Heatmap for species with abundance < 0.5%
# Done making heatmaps

# %% [markdown]
# ## Figure 3

# %%
# !python gibson_inference/figures/figure3.py \
    --mdsine_path "/content/forward_sims/"\
    --clv_elas_path "/content/clv_results/results_rel_elastic/"\
    --clv_ridge_path "/content/clv_results/results_rel_ridge/"\
    --glv_elas_path "/content/clv_results/results_abs_elastic/"\
    --glv_ridge_path "/content/clv_results/results_abs_ridge/forward_sims_abs_ridge/"\
    --output_path "gibson_inference/figures/output_figures/"
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Making Figure 3
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# Done Making Figure 3

# %% [markdown]
# ## Figure 4
#
# All sub-plots except the network diagrams for Healthy and Dysbiotic Cohorts are made. The networks are created using cytoscape and added to the figure manually using Adobe Illustrator.

# %%
# !python gibson_inference/figures/figure4.py \
    --chain_healthy "/content/mixed_prior_fixed/healthy-seed0-mixed/mcmc.pkl" \
    --chain_uc "/content/mixed_prior_fixed/uc-seed0-mixed/mcmc.pkl" \
    --tree_fname 'files/phylogenetic_placement_OTUs/phylogenetic_tree_only_query.nhx' \
    --study_healthy "output/gibson/preprocessed/gibson_healthy_agg_taxa.pkl" \
    --study_uc "output/gibson/preprocessed/gibson_uc_agg_taxa.pkl" \
    --study_inoc "output/gibson/preprocessed/gibson_inoculum_agg_taxa.pkl" \
    --detected_study_healthy "gibson_inference/figures/preprocessed_all/gibson_healthy_agg_taxa_filtered3.pkl" \
    --detected_study_uc "gibson_inference/figures/preprocessed_all/gibson_uc_agg_taxa_filtered3.pkl" \
    --output_loc "gibson_inference/figures/output_figures"
# Out:
# Making Figure 4
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# Done Making Figure 4

# %% [markdown]
# ## Figure 5
#
# This figure shows the Phylogenetic Neighborhood Analysis result, (Figure 5B).
# The cartoon (Figure 5A) is created separately.

# %%
# !python gibson_inference/figures/figure5.py \
    -file1 "/content/coarsening/distance.csv" \
    -file2 "/content/coarsening/arithmetic_mean_data.csv" \
    -file3 "/content/coarsening/arithmetic_mean_null_all.csv"
# Out:
# Making Figure 5
# gibson_inference/figures/figure5.py:71: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_xticklabels([100 - x1 for x1 in axes.get_xticks()])
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# plotted and saved gibson_inference/figures/output_figures/figure5
# Done Making Figure 5

# %% [markdown]
# ## Figure 6

# %% [markdown]
# Custom code necessary for rendering using pre-computed data.

# %%
#@title
import mdsine2 as md2
from mdsine2.names import STRNAMES
import numpy as np
import scipy
import scipy.stats
import pandas as pd
from pathlib import Path
from tqdm.notebook import tqdm
import seaborn as sns


# COLORS
_default_colors = sns.color_palette()
_default_healthy_color = _default_colors[0]
_default_uc_color = _default_colors[1]


def stat_annotate(x1, x2, y, h, color, ax, lw=1.0, desc='*'):
    ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=lw, c=color)
    ax.text((x1+x2)*.5, y+h, desc, ha='center', va='bottom', color=color)


class PerturbationSimFigure():
    """Render figures for perturbation simulations. (Figures 6A,6B)"""

    def __init__(self, data_dir: Path, healthy_color=_default_healthy_color, uc_color=_default_uc_color):
        self.healthy_color = healthy_color
        self.uc_color = uc_color

        # DATA DIR
        self.data_dir = data_dir

        # ============ Preprocessing
        print("Loading dataframes from disk.")
        healthy_random_pert_metadata_df = pd.read_hdf(
            data_dir / 'healthy_metadata.h5', key="df", mode="r")
        healthy_random_pert_fwsim_df = pd.read_hdf(
            data_dir / 'healthy_fwsim.h5', key="df", mode="r"
        )

        uc_random_pert_metadata_df = pd.read_hdf(
            data_dir / 'uc_metadata.h5', key="df", mode="r"
        )
        uc_random_pert_fwsim_df = pd.read_hdf(
            data_dir / 'uc_fwsim.h5', key="df", mode="r"
        )

        print("Merging dataframes.")
        healthy_random_pert_merged_df = self.posthoc_random_pert_helper(healthy_random_pert_fwsim_df, healthy_random_pert_metadata_df)
        uc_random_pert_merged_df = self.posthoc_random_pert_helper(uc_random_pert_fwsim_df, uc_random_pert_metadata_df)

        print("Computing difference levels.")
        self.random_pert_concat_df = self.random_pert_diff_figure_df(healthy_random_pert_merged_df, uc_random_pert_merged_df)

        print("Computing diversities.")
        self.random_pert_diversity_df, self.healthy_random_pert_baseline_diversity, self.uc_random_pert_baseline_diversity = self.precompute_diversities(
            healthy_random_pert_fwsim_df, uc_random_pert_fwsim_df
        )

        print("Finished initialization.")

    @staticmethod
    def posthoc_random_pert_helper(fwsim: pd.DataFrame, metadata: pd.DataFrame):
        merged_df = fwsim.loc[(fwsim["PerturbedFrac"] != 0.0), :].merge(
            fwsim.loc[(fwsim["PerturbedFrac"] == 0.0), ["OTU", "SteadyState", "Died", "SampleIdx"]],
            left_on=["OTU", "SampleIdx"],
            right_on=["OTU", "SampleIdx"],
            how="inner",
            suffixes=["", "Base"]
        ).merge(
            metadata.loc[
                :,
                ["OTU", "PerturbedFrac", "Perturbation", "Trial", "IsPerturbed"]
            ],
            left_on=["OTU", "PerturbedFrac", "Perturbation", "Trial"],
            right_on=["OTU", "PerturbedFrac", "Perturbation", "Trial"]
        ).set_index(["OTU", "PerturbedFrac", "Perturbation", "Trial", "SampleIdx"])

        merged_df["SteadyStateDiff"] = np.abs(np.log10(merged_df["SteadyState"] + 1e5) - np.log10(merged_df["SteadyStateBase"] + 1e5))

        return merged_df

    @staticmethod
    def random_pert_diff_figure_df(healthy_merged_df: pd.DataFrame, uc_merged_df: pd.DataFrame, perturbation=-2.0):
        #   OTU 	PerturbedFrac 	Perturbation 	Trial 	SampleIdx

        healthy_agg_df = healthy_merged_df.loc[
            (slice(None), slice(None), perturbation, slice(None), slice(None)),
            ["SteadyStateDiff"]
        ].groupby(
            level=[1, 2, 3, 4]  # "PerturbedFrac", "Perturbation", "Trial", "SampleIdx"
        ).mean().groupby(
            level=[0, 1, 2]  # "PerturbedFrac", "Perturbation", "Trial"
        ).mean()

        uc_agg_df = uc_merged_df.loc[
            (slice(None), slice(None), perturbation, slice(None), slice(None)),
            ["SteadyStateDiff"]
        ].groupby(
            level=[1, 2, 3, 4]  # "PerturbedFrac", "Perturbation", "Trial", "SampleIdx"
        ).mean().groupby(
            level=[0, 1, 2]  # "PerturbedFrac", "Perturbation", "Trial"
        ).mean()

        healthy_agg_df["Dataset"] = "Healthy"
        uc_agg_df["Dataset"] = "UC"
        concat_df = pd.concat([
            healthy_agg_df.reset_index(),
            uc_agg_df.reset_index()
        ])

        concat_df["key"] = r'$\alpha$:' + concat_df["PerturbedFrac"].astype(str) + "\nPert:" + concat_df["Perturbation"].astype(str)
        return concat_df

    @staticmethod
    def precompute_diversities(healthy_fwsim_df, uc_fwsim_df, perturbation=-2.0):
        def agg(x):
            p = x["SteadyState"].to_numpy()
            u = np.ones(p.shape[0])
            return scipy.stats.entropy(p) / scipy.stats.entropy(u)

        # ======= Altered
        healthy_diversity = healthy_fwsim_df.loc[
            (healthy_fwsim_df["PerturbedFrac"] != 0.0) & (healthy_fwsim_df["Perturbation"] == perturbation),
            ["Trial", "SampleIdx", "SteadyState", "PerturbedFrac"]
        ].groupby(["PerturbedFrac", "Trial", "SampleIdx"]).apply(
            agg
        ).groupby(level=[0, 1]).mean()
        healthy_diversity = pd.DataFrame({"Diversity": healthy_diversity})
        healthy_diversity["Dataset"] = "Healthy"

        uc_diversity = uc_fwsim_df.loc[
            (uc_fwsim_df["PerturbedFrac"] != 0.0) & (uc_fwsim_df["Perturbation"] == perturbation),
            ["Trial", "SampleIdx", "SteadyState", "PerturbedFrac"]
        ].groupby(["PerturbedFrac", "Trial", "SampleIdx"]).apply(
            agg
        ).groupby(level=[0, 1]).mean()
        uc_diversity = pd.DataFrame({"Diversity": uc_diversity})
        uc_diversity["Dataset"] = "UC"

        diversities = pd.concat([healthy_diversity.reset_index(), uc_diversity.reset_index()]).reset_index()

        # ======= Baselines
        healthy_baseline_diversity = healthy_fwsim_df.loc[
            healthy_fwsim_df["PerturbedFrac"] == 0.0,
            ["SampleIdx", "SteadyState"]
        ].groupby("SampleIdx").apply(
            agg
        ).mean()

        uc_baseline_diversity = uc_fwsim_df.loc[
            uc_fwsim_df["PerturbedFrac"] == 0.0,
            ["SampleIdx", "SteadyState"]
        ].groupby("SampleIdx").apply(
            agg
        ).mean()

        return diversities, healthy_baseline_diversity, uc_baseline_diversity

    def plot_deviations(
        self,
        ax,
        ymin=0.0, ymax=0.35
    ):
        df = self.random_pert_concat_df
        sns.swarmplot(x="PerturbedFrac",
                      y="SteadyStateDiff",
                      hue="Dataset",
                      ax=ax,
                      data=df,
                      palette={"Healthy": self.healthy_color, "UC": self.uc_color},
                      size=3,
                      dodge=True)

        sns.boxplot(
            data=df,
            x="PerturbedFrac", y="SteadyStateDiff",
            hue="Dataset",
            whis=[2.5, 97.5],
            ax=ax,
            showfliers=False,
            palette={"Healthy": self.healthy_color, "UC": self.uc_color},
            boxprops=dict(alpha=.4)
        )

        ax.set_ylim([ymin, ymax])

        # Axis labels
        ax.set_xlabel("Fraction of OTUs perturbed")
        ax.set_ylabel("Difference from Baseline Steady State")

        # =========== P-values + Benjamini-Hochberg correction
        df_healthy = df.loc[df["Dataset"] == "Healthy", ["PerturbedFrac", "SteadyStateDiff"]]
        df_uc = df.loc[df["Dataset"] == "UC", ["PerturbedFrac", "SteadyStateDiff"]]
        df_merged = df_healthy.merge(df_uc, on="PerturbedFrac", how="inner", suffixes=["Healthy", "UC"])

        # Compute statistic (raw p-values)
        def fn(tbl):
            u = scipy.stats.mannwhitneyu(tbl["SteadyStateDiffHealthy"], tbl["SteadyStateDiffUC"], alternative="less")
            return u

        pvalues = df_merged.groupby("PerturbedFrac").apply(fn)
        pvalues_df = pd.DataFrame({"pvalue": pvalues.sort_values()})

        # Apply BH correction
        p_adjusted = []
        p_adj_prev = 0.0
        for i, (index, row) in enumerate(pvalues_df.iterrows()):
            p_adj = row["pvalue"].pvalue * pvalues_df.shape[0] / (i+1)
            p_adj = min(max(p_adj, p_adj_prev), 1)
            p_adjusted.append(p_adj)
            p_adj_prev = p_adj

        pvalues_df["pvalue_adj"] = p_adjusted
        pvalues_df = pvalues_df.sort_values("PerturbedFrac").reset_index()
        sig_indices = pvalues_df.index[pvalues_df["pvalue_adj"] <= 1e-3]

        print("Pvalues for deviations")
        display(pvalues_df)

    def plot_diversity(
        self,
        ax
    ):
        diversity_df = self.random_pert_diversity_df
        healthy_baseline = self.healthy_random_pert_baseline_diversity
        uc_baseline = self.uc_random_pert_baseline_diversity

        sns.swarmplot(x="PerturbedFrac",
                      y="Diversity",
                      hue="Dataset",
                      ax=ax,
                      data=diversity_df,
                      palette={"Healthy": self.healthy_color, "UC": self.uc_color},
                      size=3,
                      dodge=True)

        sns.boxplot(
            x="PerturbedFrac",
            hue="Dataset",
            y="Diversity",
            data=diversity_df,
            ax=ax,
            whis=[2.5, 97.5],
            showfliers=False,
            palette={"Healthy": self.healthy_color, "UC": self.uc_color},
            boxprops=dict(alpha=.4)
        )

        ax.plot([-0.5, 7], [healthy_baseline] * 2, color='blue', linestyle='dashed')
        ax.plot([-0.5, 7], [uc_baseline] * 2, color='orange', linestyle='dashed')

        ax.set_ylabel("Diversity (Normalized Entropy)")
        ax.set_xlabel("Fraction of OTUs perturbed")

        # =========== P-values + Benjamini-Hochberg correction
        df_healthy = diversity_df.loc[diversity_df["Dataset"] == "Healthy", ["PerturbedFrac", "Diversity"]]
        df_uc = diversity_df.loc[diversity_df["Dataset"] == "UC", ["PerturbedFrac", "Diversity"]]
        df_merged = df_healthy.merge(df_uc, on="PerturbedFrac", how="inner", suffixes=["Healthy", "UC"])

        # Compute statistic (raw p-values)
        def fn(tbl):
            u = scipy.stats.mannwhitneyu(tbl["DiversityHealthy"], tbl["DiversityUC"], alternative="greater")
            return u

        pvalues = df_merged.groupby("PerturbedFrac").apply(fn)
        pvalues_df = pd.DataFrame({"pvalue": pvalues.sort_values()})

        # Apply BH correction
        p_adjusted = []
        p_adj_prev = 0.0
        for i, (index, row) in enumerate(pvalues_df.iterrows()):
            p_adj = row["pvalue"].pvalue * pvalues_df.shape[0] / (i+1)
            p_adj = min(max(p_adj, p_adj_prev), 1)
            p_adjusted.append(p_adj)
            p_adj_prev = p_adj

        pvalues_df["pvalue_adj"] = p_adjusted
        pvalues_df = pvalues_df.sort_values("PerturbedFrac").reset_index()
        sig_indices = pvalues_df.index[pvalues_df["pvalue_adj"] <= 1e-3]

        print("Pvalues for diversity")
        display(pvalues_df)


class EigenvalueFigure():
    def __init__(self, healthy_pickle_path, uc_pickle_path, healthy_color=_default_healthy_color, uc_color=_default_uc_color):
        self.healthy_color = healthy_color
        self.uc_color = uc_color

        print("Computing Healthy dataset eigenvalues.")
        self.healthy_eig_X = self.compute_eigenvalues(healthy_pickle_path)

        print("Computing D dataset eigenvalues.")
        self.uc_eig_X = self.compute_eigenvalues(uc_pickle_path)

    def compute_eigenvalues(self, mcmc_pickle_path, upper_bound: float = 1e20):
        # ================ Data loading
        mcmc = md2.BaseMCMC.load(mcmc_pickle_path)
        si_trace = -np.absolute(mcmc.graph[STRNAMES.SELF_INTERACTION_VALUE].get_trace_from_disk(section='posterior'))
        interactions = mcmc.graph[STRNAMES.INTERACTIONS_OBJ].get_trace_from_disk(section='posterior')

        interactions[np.isnan(interactions)] = 0
        for i in range(len(mcmc.graph.data.taxa)):
            interactions[:,i,i] = si_trace[:,i]

        # ================ Eigenvalue computation
        N = interactions.shape[0]
        M = interactions.shape[1]
        eigs = np.zeros(shape=(N, M), dtype=np.complex)
        for i in tqdm(range(N)):  # range(arr.shape[0]):
            matrix = interactions[i]

            # only for interaction matrices
            matrix = np.nan_to_num(matrix, nan=0.0)

            slice_eigs = np.linalg.eigvals(matrix)

            # Throw out samples where eigenvalues blow up
            if np.sum(np.abs(slice_eigs) > upper_bound) > 0:
                print("Upper bound threshold {th} passed for sample {i}; skipping.".format(
                    th=upper_bound,
                    i=i
                ))
                continue

            eigs[i, :] = slice_eigs

        # Get real positive parts only.
        eigs = eigs.real.flatten()
        return eigs[eigs > 0]

    def plot(self, ax, alpha: float = 0.7):
        ####################################################
        # Eigenvalue histogram.
        ####################################################

        bins = np.linspace(0, 5e-9, 45)
        sns.histplot(self.uc_eig_X, ax=ax, bins=bins, label='Dysbiosis',
                     alpha=alpha, color=self.uc_color)
        sns.histplot(self.healthy_eig_X, ax=ax, bins=bins, label='Healthy',
                     alpha=alpha, color=self.healthy_color)

        ax.set_xlabel('Pos. Real Part of Eigenvalues', labelpad=20)
        ax.set_ylabel('Total count with multiplicity')
        ax.ticklabel_format(style="sci", scilimits=(0,0), useMathText=True, useOffset=False)


class CycleFigure():
    def __init__(self, healthy_pickle_path, uc_pickle_path, healthy_color=_default_healthy_color, uc_color=_default_uc_color):
        self.healthy_color = healthy_color
        self.uc_color = uc_color

        self.healthy_pickle_path = healthy_pickle_path
        self.uc_pickle_path = uc_pickle_path

        healthy_fixed_cluster = MdsineOutput(
            "Healthy",
            self.healthy_pickle_path
        )
        uc_fixed_cluster = MdsineOutput(
            "UC",
            self.uc_pickle_path
        )

        print("Computing cycles for Healthy dataset.")
        self.healthy_signed_cycles = self.compute_signed_statistics(
            healthy_fixed_cluster.get_clustered_interactions()
        )

        print("Computing cycles for Dysbiotic dataset.")
        self.uc_signed_cycles = self.compute_signed_statistics(
            uc_fixed_cluster.get_clustered_interactions()
        )
        self.n_samples = 10000

    def compute_signed_statistics(self, interactions):
        """
        Loop through each gibbs sample. For each gibbs sample, compute the number of cycles, assorted by sign.
        (Does not tell us exactly which cycles appear frequently.)
        """
        N = interactions.shape[0]
        ans = {
            '++': np.zeros(N),
            '--': np.zeros(N),
            '+-': np.zeros(N),
            '+++': np.zeros(N),
            '---': np.zeros(N),
            '++-': np.zeros(N),
            '--+': np.zeros(N)
        }
        for idx, mat in tqdm(enumerate(interactions), total=N):
            signed_cycle_counts = self.count_signed_cycles(mat)
            for sgn, counts in ans.items():
                counts[idx] = signed_cycle_counts[sgn]
        return ans

    def count_signed_cycles(self, mat):
        '''
        Count length 2 and 3 cycles, given a particular interaction matrix (corresp. to a single gibbs sample).
        '''
        adj = np.copy(mat).T
        plus_adj = np.zeros(shape=adj.shape, dtype=np.int)
        plus_adj[adj > 0] = 1
        minus_adj = np.zeros(shape=adj.shape, dtype=np.int)
        minus_adj[adj < 0] = 1

        return {
            '++': self.count_cycles_with_sign(['++'], plus_adj, minus_adj) / 2,
            '--': self.count_cycles_with_sign(['--'], plus_adj, minus_adj) / 2,
            '+-': self.count_cycles_with_sign(['+-', '-+'], plus_adj, minus_adj) / 2,
            '+++': self.count_cycles_with_sign(['+++'], plus_adj, minus_adj) / 3,
            '---': self.count_cycles_with_sign(['---'], plus_adj, minus_adj) / 3,
            '++-': self.count_cycles_with_sign(['++-', '+-+', '-++'], plus_adj, minus_adj) / 3,
            '--+': self.count_cycles_with_sign(['--+', '-+-', '+--'], plus_adj, minus_adj) / 3,
        }

    @staticmethod
    def count_cycles_with_sign(signs, plus, minus):
        """
        Multiply adjacency matrices to count the number of cycles. Example: #(+-+) = Trace[(M+) * (M-) * (M+)]
        """
        ans = 0
        for pattern in signs:
            M = np.eye(plus.shape[0])
            for sign in pattern:
                if sign == "+":
                    M = M @ plus
                elif sign == "-":
                    M = M @ minus
            ans = ans + np.sum(np.diag(M))
        return ans

    def plot(self, ax):
        lengths = [2, 3]
        signs = ['++', '--', '+-', '+++', '---', '++-', '--+']
        sign_order = {
            "({})".format(" ".join(sgn)): i for i, sgn in enumerate(signs)
        }
        df = pd.DataFrame(columns=["Count"],
                          dtype=np.float,
                          index=pd.MultiIndex.from_product(
                              [signs, range(self.n_samples), ["Healthy", "UC"]],
                              names=["Sign", "Index", "Dataset"]
                          ))

        for pattern in signs:
            df.loc[(pattern, slice(None), "Healthy")] = self.healthy_signed_cycles[pattern].reshape(-1, 1)
            df.loc[(pattern, slice(None), "UC")] = self.uc_signed_cycles[pattern].reshape(-1, 1)

        df = df.reset_index()
        df["Sign"] = df["Sign"].map({
            "++": "(+ +)",
            "--": "(- -)",
            "+-": "(+ -)",
            "+++": "(+ + +)",
            "---": "(- - -)",
            "++-": "(+ + -)",
            "--+": "(- - +)",
        })

        medianprops = dict(linestyle='--', linewidth=2.5)

        sns.violinplot(x="Sign",
                       y="Count",
                       hue="Dataset", data=df,
                       ax=ax,
                       scale="count",
                       cut=0,
    #                    inner="quartile",
                       bw=0.5,
                       palette={"Healthy": self.healthy_color, "UC": self.uc_color})

        # =========== P-values + Benjamini-Hochberg correction
        df_healthy = df.loc[df["Dataset"] == "Healthy", ["Sign", "Index", "Count"]]
        df_uc = df.loc[df["Dataset"] == "UC", ["Sign", "Index", "Count"]]
        df_merged = df_healthy.merge(
            df_uc,
            left_on=["Sign", "Index"],
            right_on=["Sign", "Index"],
            how="inner",
            suffixes=["Healthy", "UC"]
        )

        # Compute statistic (raw p-values)
        def fn(tbl):
            u = scipy.stats.mannwhitneyu(
                tbl["CountHealthy"], tbl["CountUC"],
                alternative="less"
            )
            return u

        pvalues = df_merged.groupby(
            "Sign"
        ).apply(fn)

        pvalues_df = pd.DataFrame(
            {"pvalue": pvalues.sort_values()}
        )

        # Apply BH correction
        p_adjusted = []
        p_adj_prev = 0.0
        for i, (index, row) in enumerate(pvalues_df.iterrows()):
            p_adj = row["pvalue"].pvalue * pvalues_df.shape[0] / (i+1)
            p_adj = min(max(p_adj, p_adj_prev), 1)
            p_adjusted.append(p_adj)
            p_adj_prev = p_adj

        pvalues_df["pvalue_adj"] = p_adjusted



        pvalues_df = pvalues_df.reset_index()
        sig_signs = pvalues_df.loc[pvalues_df["pvalue_adj"] <= 1e-3, "Sign"]
        display(pvalues_df)

        for sgn in sig_signs:
            idx = sign_order[sgn]
            pval = pvalues_df.loc[pvalues_df['Sign'] == sgn, 'pvalue_adj'].item()
            if pval <= 1e-4:
                indicator = "****"
            elif pval <= 1e-3:
                indicator = "***"
            else:
                indicator = "ERR"
            y = df.loc[df['Sign'] == sgn, "Count"].max()
            stat_annotate(idx-0.5, idx+0.5, y=y, h=0.5, ax=ax, color='black', desc=indicator)
        ax.set_ylabel("Number of cycles per sample")


# Preprocessing for Cycles (Figure F)
class MdsineOutput(object):
    '''
    A class to encode the data output by MDSINE.
    '''
    def __init__(self, dataset_name, pkl_path):
        self.dataset_name = dataset_name
        self.mcmc = md2.BaseMCMC.load(pkl_path)
        self.taxa = self.mcmc.graph.data.taxa
        self.name_to_taxa = {otu.name: otu for otu in self.taxa}

        self.interactions = None
        self.clustering = None

        self.clusters_by_idx = {
            (c_idx): [self.get_taxa(oidx) for oidx in cluster.members]
            for c_idx, cluster in enumerate(self.get_clustering())
        }

    @property
    def num_samples(self) -> int:
        return self.mcmc.n_samples

    def get_cluster_df(self):
        return pd.DataFrame([
            {
                "id": cluster.id,
                "idx": c_idx+1,
                "otus": ",".join([self.get_taxa(otu_idx).name for otu_idx in cluster.members]),
                "size": len(cluster)
            }
            for c_idx, cluster in enumerate(self.clustering)
        ])

    def get_interactions(self):
        if self.interactions is None:
            self.interactions = self.mcmc.graph[STRNAMES.INTERACTIONS_OBJ].get_trace_from_disk(section='posterior')
        return self.interactions

    def get_taxa(self, idx):
        return self.taxa.index[idx]

    def get_taxa_by_name(self, name: str):
        return self.name_to_taxa[name]

    def get_taxa_str(self, idx):
        tax = self.taxa.index[idx].taxonomy
        family = tax["family"]
        genus = tax["genus"]
        species = tax["species"]

        if genus == "NA":
            return "{}**".format(family)
        elif species == "NA":
            return "{}, {}*".format(family, genus)
        else:
            return "{}, {} {}".format(family, genus, species)

    def get_taxa_str_long(self, idx):
        return "{}\n[{}]".format(self.get_taxa(idx).name, self.get_taxa_str(idx))

    def get_clustering(self):
        if self.clustering is None:
            self.clustering = self.mcmc.graph[STRNAMES.CLUSTERING_OBJ]
            for cidx, cluster in enumerate(self.clustering):
                cluster.idx = cidx
        return self.clustering

    def get_clustered_interactions(self):
        clusters = self.get_clustering()
        otu_interactions = self.get_interactions()
        cluster_interactions = np.zeros(
            shape=(
                otu_interactions.shape[0],
                len(clusters),
                len(clusters)
            ),
            dtype=np.float
        )
        cluster_reps = [
            next(iter(cluster.members)) for cluster in clusters
        ]
        for i in range(cluster_interactions.shape[0]):
            cluster_interactions[i] = otu_interactions[i][np.ix_(cluster_reps, cluster_reps)]
        return cluster_interactions

# %% [markdown]
# ### Figure 6A + 6B
#
# A: Deviation from unperturbed steady state for random perturbations on a random α-fraction of taxa.
#
# B: Change in α-diversity for the same set of simulated trajectories.

# %%
pert_path = "/content/fwsim_random_pert"
pert_fig = PerturbationSimFigure(Path(
    pert_path  # Used to be /data/cctm/darpa_perturbation_mouse_study/youn_notebooks/fwsim_random_pert
))

fig, axes = plt.subplots(2, 1, figsize=(15,20))

pert_fig.plot_deviations(axes[0], ymin=0.0, ymax=1.5)
pert_fig.plot_diversity(axes[1])
fig.savefig("{}/figure6ab.pdf".format(saveloc))
# Out:
# Loading dataframes from disk.
# Merging dataframes.
# Computing difference levels.
# Computing diversities.
# Finished initialization.
# <div id='cb37298e-a53a-4e9e-ad45-c5a50eb77c9a'></div>
# Pvalues for deviations
#    PerturbedFrac             pvalue  pvalue_adj
# 0            0.1  (29450000.0, 0.0)         0.0
# 1            0.2  (22840000.0, 0.0)         0.0
# 2            0.3   (9980000.0, 0.0)         0.0
# 3            0.4   (7240000.0, 0.0)         0.0
# 4            0.5   (3910000.0, 0.0)         0.0
# 5            0.6   (4770000.0, 0.0)         0.0
# 6            0.7  (15010000.0, 0.0)         0.0
# Pvalues for diversity
#    PerturbedFrac              pvalue  pvalue_adj
# 0            0.1  (100000000.0, 0.0)         0.0
# 1            0.2   (99540000.0, 0.0)         0.0
# 2            0.3   (99920000.0, 0.0)         0.0
# 3            0.4   (98190000.0, 0.0)         0.0
# 4            0.5   (95580000.0, 0.0)         0.0
# 5            0.6   (98910000.0, 0.0)         0.0
# 6            0.7   (99000000.0, 0.0)         0.0

# %% [markdown]
# ### Figure 6C
#
# Histogram of real, positive parts of eigenvalues.

# %%
mcmc_healthy_path_unfixed = "/content/mixed_prior_unfixed/healthy-seed0-mixed/mcmc.pkl"
mcmc_uc_path_unfixed = "/content/mixed_prior_unfixed/uc-seed0-mixed/mcmc.pkl"
eig_fig = EigenvalueFigure(mcmc_healthy_path_unfixed, mcmc_uc_path_unfixed)

fig, ax = plt.subplots(1, 1, figsize=(15, 10))
eig_fig.plot(ax)
fig.savefig("{}/figure6c.pdf".format(saveloc))
# Out:
# Computing Healthy dataset eigenvalues.
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Computing D dataset eigenvalues.
#   0%|          | 0/10000 [00:00<?, ?it/s]
# <div id='69a64f47-d161-4d1e-ab5a-e30f8d4dd311'></div>

# %% [markdown]
# ## Figure 6D
#
# Counting of module-level simple cycles.

# %%
mcmc_healthy_path_fixed = "/content/mixed_prior_fixed/healthy-seed0-mixed/mcmc.pkl"
mcmc_uc_path_fixed = "/content/mixed_prior_fixed/uc-seed0-mixed/mcmc.pkl"
cycle_fig = CycleFigure(
    mcmc_healthy_path_fixed, # Fixed clustering run
    mcmc_uc_path_fixed  # Fixed clustering run
)

fig, ax = plt.subplots(1, 1, figsize=(15, 10))
cycle_fig.plot(ax)
fig.savefig("{}/figure6d.pdf".format(saveloc))
# Out:
# Computing cycles for Healthy dataset.
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Computing cycles for Dysbiotic dataset.
#   0%|          | 0/10000 [00:00<?, ?it/s]
# <div id='0b299f70-9187-4d1d-8e12-bb185cf7a90e'></div>
#       Sign             pvalue  pvalue_adj
# 0    (- -)   (1126591.0, 0.0)         0.0
# 1  (- - -)   (6691867.0, 0.0)         0.0
# 2  (- - +)  (27543922.0, 0.0)         0.0
# 3    (+ +)  (58805465.0, 1.0)         1.0
# 4  (+ + -)  (60414415.0, 1.0)         1.0
# 5    (+ -)  (63280757.0, 1.0)         1.0
# 6  (+ + +)  (67927982.0, 1.0)         1.0

# %% [markdown]
# ## Figure 7

# %% [markdown]
# Custom code necessary for rendering Keystoneness figure.

# %%
#@title
import numpy as np
import mdsine2 as md2
from tqdm.notebook import tqdm
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm, gridspec
import matplotlib.colors as mcolors
import seaborn as sns


def cluster_nonmembership_df(md):
    entries = []
    for cluster in md.get_clustering():
        for otu in md.taxa:
            if otu.idx not in cluster.members:
                entries.append({
                    "ClusterID": cluster.id,
                    "OTU": otu.name
                })
    return pd.DataFrame(entries)


def cluster_membership_df(md):
    entries = []
    for cluster in md.get_clustering():
        for oidx in cluster.members:
            otu = md.get_taxa(oidx)
            entries.append({
                "ClusterOfOTU": cluster.id,
                "OTU": otu.name
            })
    return pd.DataFrame(entries)


def create_cmap(tag, nan_value="red"):
    cmap = cm.get_cmap(tag)
    cmap.set_bad(color=nan_value)
    return cmap


class KeystonenessFigure():
    def __init__(self, dataset_name: str, mcmc_pickle_path, subjset_path, fwsim_path):
        print("Loading pickle files.")
        self.md = MdsineOutput(dataset_name, mcmc_pickle_path)
        self.study = md2.Study.load(subjset_path)
        
        print("Loading dataframe from disk.")
        self.fwsim_df = pd.read_hdf(fwsim_path, key='df', mode='r')
        
        print("Compiling dataframe.")
        self.ky_df = self.generate_keystoneness_df()
        
        print("Compiling abundance data.")
        self.abundance_array = self.get_abundance_array()
        
        print("Extracting keystoneness values.")
        self.ky_array = self.get_ky_array()
        
        print("Extracting baseline abundances.")
        self.day20_array = self.get_day20_abundances()

    def generate_keystoneness_df(self):
        md = self.md
        fwsim_df = self.fwsim_df
        
        nonmembers_df = cluster_nonmembership_df(md)

        baseline = fwsim_df.loc[fwsim_df["ExcludedCluster"] == "None"]

        altered = fwsim_df.loc[fwsim_df["ExcludedCluster"] != "None"]
        altered = altered.merge(
            right=nonmembers_df,
            how="inner",
            left_on=["ExcludedCluster", "OTU"],
            right_on=["ClusterID", "OTU"]
        )

        merged = altered.merge(
            baseline[["OTU", "SampleIdx", "StableState"]],
            how="left",
            left_on=["OTU", "SampleIdx"],
            right_on=["OTU", "SampleIdx"],
            suffixes=["", "Base"] 
        )
        
        merged["DiffStableState"] = np.log10(merged["StableStateBase"] + 1e5) - np.log10(merged["StableState"] + 1e5)

        return merged[
            ["ExcludedCluster", "SampleIdx", "DiffStableState"]
        ].groupby(
            ["ExcludedCluster", "SampleIdx"]
        ).mean().rename(columns={"DiffStableState": "Ky"})
    
    def get_abundance_array(self):
        md = self.md
        fwsim_df = self.fwsim_df
        
        clustering = md.get_clustering()
        membership_df = cluster_membership_df(md)
        merged_df = fwsim_df.merge(
            membership_df,
            how="left",
            left_on="OTU",
            right_on="OTU"
        )
        
        abund_array = np.zeros(shape=(len(clustering) + 1, len(clustering)))

        # Baseline abundances (no cluster removed) -- sum across OTUs (per sample), median across samples.
        subset_df = merged_df.loc[merged_df["ExcludedCluster"] == "None"]
        subset_df = subset_df[
            ["ClusterOfOTU", "SampleIdx", "StableState"]
        ].groupby(
            ["ClusterOfOTU", "SampleIdx"]
        ).sum(
            # Aggregate over OTUs  (e.g. Baseline abundance of a cluster is the sum of its constituents.)
        ).groupby(
            level=0
        ).median(
            # Aggregate over samples
        )
        for cluster in clustering:
            abund_array[0, cluster.idx] = subset_df.loc[cluster.id]

        # Altered abundances (remove 1 cluster at a time)
        for removed_cluster in tqdm(clustering, total=len(clustering), desc="Heatmap Abundances"):
            subset_df = merged_df.loc[merged_df["ExcludedCluster"] == removed_cluster.id]

            # Compute the total abundance (over OTUs) for each cluster, for each sample. Then aggregate (median) across samples.
            subset_df = subset_df[
                ["ClusterOfOTU", "SampleIdx", "StableState"]
            ].groupby(
                ["ClusterOfOTU", "SampleIdx"]
            ).sum(
                # Aggregate over OTUs
            ).groupby(
                level=0
            ).median(
                # Aggregate over samples
            )

            for cluster in clustering:
                abund_array[removed_cluster.idx + 1, cluster.idx] = subset_df.loc[cluster.id]
        return abund_array
    
    def get_ky_array(self):
        # Group by Cluster, aggregate (mean/median) across samples.
        agg_ky_df = self.ky_df.groupby(level=0).median()
        return np.array(
            [agg_ky_df.loc[cluster.id, "Ky"] for cluster in self.md.get_clustering()]
        )
    
    def get_day20_abundances(self):
        M = self.study.matrix(dtype='abs', agg='mean', times='intersection', qpcr_unnormalize=True)
        day20_state = M[:, 19]
        cluster_day20_abundances = np.zeros(len(self.md.get_clustering()))

        for cidx, cluster in enumerate(self.md.get_clustering()):
            cluster_day20_abundances[cidx] = np.sum(
                [day20_state[oidx] for oidx in cluster.members]
            )
        return cluster_day20_abundances
    
    def plot(self, fig):
        md = self.md
        abund_array = self.abundance_array
        ky_array = self.ky_array
        day20_array = self.day20_array
        
        # Main abundance grid shows the _difference_ from baseline, instead of the abundances itself.
        n_clusters = len(ky_array)

        # =========== Pre-sorting. ===========
        ky_order = np.argsort(ky_array)
        ky_order = ky_order[::-1]
        ky_array = ky_array[ky_order]

        day20_array = day20_array[ky_order].reshape(1, len(day20_array))

        baseline_array = abund_array[[0], :]
        baseline_array = baseline_array[:, ky_order]

        altered_array = abund_array[1 + ky_order, :]  # Reorder the rows first (exclude the baseline row),
        altered_array = altered_array[:, ky_order]  # Then reorder the columns.

        baseline_diff_array = np.log10(baseline_array + 1e5) - np.log10(altered_array + 1e5)
        for i in range(baseline_diff_array.shape[0]):
            baseline_diff_array[i, i] = np.nan

        # =========== Heatmap settings. ========
        gridspec_kw = {"height_ratios":[1, 1, abund_array.shape[0] - 1], "width_ratios" : [1, abund_array.shape[1]]}

        # Colors and normalization (abund)
        abund_min = np.max([
            np.min(abund_array[abund_array > 0]), 
            1e5
        ])
        abund_max = np.min([
            np.max(abund_array[abund_array > 0]),
            1e13
        ])
        print("abund_min = {}, abund_max = {}".format(abund_min, abund_max))

        abund_cmap = create_cmap("Greens", nan_value="white")
        abund_norm = matplotlib.colors.LogNorm(vmin=abund_min, vmax=abund_max)

        # Colors and normalization (Ky)
        gray = np.array([0.95, 0.95, 0.95, 1.0])
        red = np.array([1.0, 0.0, 0.0, 1.0])
        blue = np.array([0.0, 0.0, 1.0, 1.0])
        n_interp=128

        top = blue
        bottom = red
        top_middle = 0.05 * top + 0.95 * gray
        bottom_middle = 0.05 * bottom + 0.95 * gray

        ky_cmap = matplotlib.colors.ListedColormap(
            np.vstack(
                [(1-t) * bottom + t * bottom_middle for t in np.linspace(0, 1, n_interp)]
                +
                [(1-t) * top_middle + t * top for t in np.linspace(0, 1, n_interp)]
            ),
            name='Keystoneness'
        )
        ky_cmap.set_bad(color="white")


        ky_min = 0.90 * np.min(ky_array) + 0.10 * np.min(baseline_diff_array[altered_array > 0])
        ky_max = 0.90 * np.max(ky_array) + 0.10 * np.max(baseline_diff_array[altered_array > 0])

        ky_norm = matplotlib.colors.TwoSlopeNorm(vmin=ky_min, vcenter=0, vmax=ky_max)
        def _forward(x):
            y = x.copy()
            positive_part = x[x > 0]
            y[x > 0] = np.sqrt(positive_part / ky_max)

            negative_part = x[x < 0]
            y[x < 0] = -np.sqrt(np.abs(negative_part / ky_min))
            return y
        def _reverse(x):
            y = x.copy()
            positive_part = x[x > 0]
            y[x > 0] = ky_max * np.power(positive_part, 2)

            negative_part = x[x < 0]
            y[x < 0] = -np.abs(ky_min) * np.power(negative_part, 2)
            return y
        ky_norm = matplotlib.colors.FuncNorm((_forward, _reverse), vmin=ky_min, vmax=ky_max)

        # Seaborn Heatmap Kwargs
        abund_heatmapkws = dict(square=False, 
                                cbar=False, 
                                cmap=abund_cmap, 
                                linewidths=0.5,
                                norm=abund_norm)
        ky_heatmapkws = dict(square=False, cbar=False, cmap=ky_cmap, linewidths=0.5, norm=ky_norm)

        # ========== Plot layout ===========
    #     [left, bottom, width, height]
        main_x = 0.67
        main_y = 0.5
        box_unit = 0.03
        main_width = box_unit * n_clusters
        main_height = main_width
        main_left = main_x - 0.5 * main_width
        main_bottom = main_y - 0.5 * main_width
        print("Left: {}, bottom: {}, width: {}, height: {}".format(main_left, main_bottom, main_width, main_height))
        print("Right: {}, Top: {}".format(main_left + main_width, main_bottom + main_height))

        ky_ax = fig.add_axes([main_left + main_width + 0.5 * box_unit, main_bottom, box_unit, main_height])
        abundances_ax = fig.add_axes([main_left, main_bottom, main_width, main_height])
        obs_ax = fig.add_axes([main_left, main_bottom + main_height + 1.5 * box_unit, box_unit * n_clusters, box_unit])
        baseline_ax = fig.add_axes([main_left, main_bottom + main_height + 0.5 * box_unit, box_unit * n_clusters, box_unit])

        # ========= Rendering. ==========
        # ====== Bottom left: Keystoneness
        hmap_ky = sns.heatmap(
            ky_array.reshape(len(ky_array), 1),
            ax=ky_ax,
            xticklabels=False,
            yticklabels=False,
            **ky_heatmapkws
        )
        hmap_ky.xaxis.set_tick_params(width=0)
        fig.text(main_left + main_width + 2*box_unit, main_y, "Keystoneness", ha='center', va='center', rotation=-90)

        for _, spine in hmap_ky.spines.items():
            spine.set_visible(True)
            spine.set_linewidth(1.0)

        # ====== Top right 1: Observed levels (day 20)
        hmap_day20_abund = sns.heatmap(day20_array, 
                                       ax=obs_ax, 
                                       xticklabels=False, 
                                       yticklabels=["Observation"],
                                       **abund_heatmapkws)
        hmap_day20_abund.set_yticklabels(hmap_day20_abund.get_yticklabels(), rotation=0)
        for _, spine in hmap_day20_abund.spines.items():
            spine.set_visible(True)
            spine.set_linewidth(1.0)
        fig.text(main_x, main_bottom + main_height + 3 * box_unit, "Steady State Abundance", ha='center', va='center')

        # ====== Top right 2: Baseline abundances
        hmap_base_abund = sns.heatmap(baseline_array, 
                                      ax=baseline_ax, 
                                      xticklabels=False, 
                                      yticklabels=["Simulation"],
                                      **abund_heatmapkws)
        hmap_base_abund.set_yticklabels(hmap_base_abund.get_yticklabels(), rotation=0)
        for _, spine in hmap_base_abund.spines.items():
            spine.set_visible(True)
            spine.set_linewidth(1.0)

        # ====== Bottom right: Abundances with clusters removed.
        ticklabels = [
            "{}{}".format(
                "H" if md.dataset_name == "Healthy" else "D", 
                c_idx + 1
            ) 
            for c_idx in ky_order
        ]
        hmap_removed_cluster_abund = sns.heatmap(
            baseline_diff_array, 
            ax=abundances_ax, 
            xticklabels=ticklabels, 
            yticklabels=ticklabels, 
            **ky_heatmapkws
        )
        # Draw a marker ("X") on top of NaNs.
        abundances_ax.scatter(*np.argwhere(np.isnan(baseline_diff_array.T)).T + 0.5, marker="x", color="black", s=100)
        abundances_ax.set_ylabel("Module Removed")
        abundances_ax.set_xlabel("Per-Module Change")
        for _, spine in hmap_removed_cluster_abund.spines.items():
            spine.set_visible(True)
            spine.set_linewidth(1.0)
        hmap_removed_cluster_abund.xaxis.set_ticks_position('bottom')
        hmap_removed_cluster_abund.set_xticklabels(
            hmap_removed_cluster_abund.get_xticklabels(), rotation=90, horizontalalignment='center'
        )
        abundances_ax.tick_params(direction='out', length=0, width=0)

        # ======= Draw the colormaps ========
        cbar_from_main = 0.25
        cbar_width = 0.01
        cbar_height = 0.35

        # Cbar on the right (steady state diff, green)
        cax = fig.add_axes([main_left - cbar_from_main, main_y - 0.5 * cbar_height, cbar_width, cbar_height])
        sm = matplotlib.cm.ScalarMappable(cmap=abund_cmap, norm=abund_norm)
        sm.set_array(np.array([]))
        cbar = fig.colorbar(sm, cax=cax)

        yticks = cbar.get_ticks()
        yticklabels = [str(np.log10(y)) for y in yticks]
        yticklabels[0] = "<{}".format(yticklabels[0])  
        cax.set_yticklabels(yticklabels)
        cax.set_ylabel("Log-Abundance")

        # Cbar on the left (Keyst., RdBu)
        cax = fig.add_axes([main_left - cbar_from_main - 2*cbar_width, main_y - 0.5 * cbar_height, cbar_width, cbar_height])
        sm = matplotlib.cm.ScalarMappable(cmap=ky_cmap, norm=ky_norm)
        sm.set_array(np.array([]))
        cbar = fig.colorbar(sm, cax=cax)
        cax.yaxis.set_ticks_position('left')
        cax.set_ylabel("Log-Difference from Base")
        cax.yaxis.set_label_position("left")

        yticks = cbar.get_ticks()
        yticklabels = ["{:.1f}".format(y) for y in yticks]
        cax.set_yticklabels(yticklabels)

        # Legend label text
        fig.text(
            main_left - cbar_from_main - cbar_width,
            main_y + 0.5 * cbar_height + 0.05,
            "Legend",
            ha='center', va='center',
            fontweight='bold'
        )

# %% [markdown]
# ###Healthy Keystoneness values

# %%
healthy_subjset_path = "/content/MDSINE2_Paper/analysis/output/gibson/preprocessed/gibson_healthy_agg_taxa_filtered.pkl"
healthy_keystone_path = "/content/keystoneness/healthy_fwsim_day20.h5"
fig = plt.figure(figsize=(10,10))
KeystonenessFigure(
    "Healthy",
    mcmc_healthy_path_fixed,  # Fixed clustering run
    healthy_subjset_path,
    healthy_keystone_path  # Used to be: darpa_perturbation_mouse_study/youn_notebooks/keystoneness/healthy_fwsim_day20.h5
).plot(fig)
fig.savefig("{}/figure7_healthy.pdf".format(saveloc))
# Out:
# <div id='c02239d4-9a76-423d-ab8a-5e5b2189865b'></div>
# Loading pickle files.
# Loading dataframe from disk.
# Compiling dataframe.
# Compiling abundance data.
# Heatmap Abundances:   0%|          | 0/16 [00:00<?, ?it/s]
# Extracting keystoneness values.
# Extracting baseline abundances.
# abund_min = 100000.0, abund_max = 1792080038491.396
# Left: 0.43000000000000005, bottom: 0.26, width: 0.48, height: 0.48
# Right: 0.91, Top: 0.74

# %% [markdown]
# ###Dysbiosis Keystoneness values

# %%
uc_subjset_path = "/content/MDSINE2_Paper/analysis/output/gibson/preprocessed/gibson_uc_agg_taxa_filtered.pkl"
uc_keystone_path = "/content/keystoneness/uc_fwsim_day20.h5"
fig = plt.figure(figsize=(10,10))

KeystonenessFigure(
    "Dysbiotic",
    mcmc_uc_path_fixed,  # Fixed clustering run
    uc_subjset_path,
    uc_keystone_path  # Used to be: darpa_perturbation_mouse_study/youn_notebooks/keystoneness/uc_fwsim_day20.h5
).plot(fig)
fig.savefig("{}/figure7_dysbiotic.pdf".format(saveloc))
# Out:
# <div id='e451c09e-f757-49c2-ace3-e62b7a44eafe'></div>
# Loading pickle files.
# Loading dataframe from disk.
# Compiling dataframe.
# Compiling abundance data.
# Heatmap Abundances:   0%|          | 0/11 [00:00<?, ?it/s]
# Extracting keystoneness values.
# Extracting baseline abundances.
# abund_min = 100000.0, abund_max = 176990392517.16693
# Left: 0.5050000000000001, bottom: 0.335, width: 0.32999999999999996, height: 0.32999999999999996
# Right: 0.8350000000000001, Top: 0.665

# %% [markdown]
# ## Supplemental Figure 1

# %%
# !python gibson_inference/figures/supplemental_figure1.py \
-file1 "gibson_inference/figures/preprocessed_all/gibson_healthy_agg_taxa.pkl" \
-file2 "gibson_inference/figures/preprocessed_all/gibson_uc_agg_taxa.pkl" \
-file3 "gibson_inference/figures/preprocessed_all/gibson_inoculum_agg_taxa.pkl"
# Out:
# Making Supplemental Figure 1
# Plotting Beta Diversity
# Plotting Alpha Diversity
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# Permanova Test Result
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                     688
# number of groups                  2
# test statistic              260.746
# p-value                       0.001
# number of permutations          999
# Name: PERMANOVA results, dtype: object
# Done Making Supplemental Figure 1

# %% [markdown]
# ## Supplemental Figure 2
#
# The whole figure is created in multiple steps. In the first step we plot, the relative abundance at the phylum level. Then, we separately make the heatmaps showing the deseq results. The final figure is made by combining the sub-figures in Adobe illustrator.

# %% [markdown]
# ###First Step

# %%
# !python gibson_inference/figures/supplemental_figure2.py \
    -file1 "gibson_inference/figures/preprocessed_all/gibson_healthy_agg_taxa.pkl" \
    -file2 "gibson_inference/figures/preprocessed_all/gibson_uc_agg_taxa.pkl" \
    -file3 "gibson_inference/figures/preprocessed_all/gibson_inoculum_agg_taxa.pkl"
# Out:
# Making Supplemental Figure 2
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# Done Making Supplemental Figure 2

# %% [markdown]
# ###Heatmap showing DeSeq results at steady state at phylum level
#
# The heatmaps are saved as mat_phylum_high_ss and mat_phylum_low_ss.

# %%
# !python gibson_inference/figures/deseq_heatmap_ss.py \
    -loc "gibson_inference/figures/supplemental_figure2_files" \
    -abund "high" \
    -txt "abundant_species_phylum" \
    -taxo "phylum" \
    -o "mat_phylum_high_ss" \
    -o_loc "gibson_inference/figures/output_figures"


# !python gibson_inference/figures/deseq_heatmap_ss.py \
    -loc "gibson_inference/figures/supplemental_figure2_files" \
    -abund "low" \
    -txt "abundant_species_phylum" \
    -taxo "phylum" \
    -o "mat_phylum_low_ss" \
    -o_loc "gibson_inference/figures/output_figures"
# Out:
# Making Heatmap for species with abundance > 0.5%
# Done making heatmaps
# Making Heatmap for species with abundance < 0.5%
# Done making heatmaps

# %% [markdown]
# ####Heatmap showing DeSeq results for different perturbations at phylum level
# The heatmaps are saved as mat_phylum_high and mat_phylum_low.

# %%
# !python gibson_inference/figures/deseq_heatmap_phylum.py \
    -loc "gibson_inference/figures/supplemental_figure2_files" \
    -abund "high" \
    -txt "abundant_species_phylum" \
    -taxo "phylum" \
    -o "mat_phylum_high" \
    -o_loc "gibson_inference/figures/output_figures"


# !python gibson_inference/figures/deseq_heatmap_phylum.py \
    -loc "gibson_inference/figures/supplemental_figure2_files" \
    -abund "low" \
    -txt "abundant_species_phylum" \
    -taxo "phylum" \
    -o "mat_phylum_low" \
    -o_loc "gibson_inference/figures/output_figures"

# %% [markdown]
# ###Heatmap showing results of DeSeq analysis at Order level
#
# The heatmaps are saved as mat_order_high and mat_order_low.

# %%
# !python gibson_inference/figures/deseq_heatmap_order.py \
    -loc "gibson_inference/figures/supplemental_figure2_files" \
    -abund "high" \
    -txt "abundant_species_order" \
    -taxo "order" \
    -o "mat_order_high" \
    -o_loc "gibson_inference/figures/output_figures"


# !python gibson_inference/figures/deseq_heatmap_order.py \
    -loc "gibson_inference/figures/supplemental_figure2_files" \
    -abund "low" \
    -txt "abundant_species_order" \
    -taxo "order" \
    -o "mat_order_low" \
    -o_loc "gibson_inference/figures/output_figures"

# %% [markdown]
# ## Supplemental Figure 3

# %%
# !python gibson_inference/figures/supplemental_figure3.py \
    -file1 "output/gibson/preprocessed/gibson_healthy_agg_taxa.pkl" \
    -file2 "output/gibson/preprocessed/gibson_uc_agg_taxa.pkl" \
# Out:
# Making Supplemental Figure 3
# subj number: 1
# subj number: 2
# used: 113
# subj number: 3
# subj number: 4
# subj number: 7
# subj number: 8
# used: 94
# subj number: 9
# subj number: 10
# subj number: 11
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# Done Making Supplemental Figure 3

# %% [markdown]
# ## Supplemental Figure 4

# %%
# !python gibson_inference/figures/supplemental_figure4.py \
    --mdsine_path "/content/forward_sims/"\
    --clv_elas_path "/content/clv_results/results_rel_elastic/"\
    --clv_ridge_path "/content/clv_results/results_rel_ridge/"\
    --glv_elas_path "/content/clv_results/results_abs_elastic/"\
    --glv_ridge_path "/content/clv_results/results_abs_ridge/forward_sims_abs_ridge/"\
    --output_path "gibson_inference/figures/output_figures/"
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Making Supplemental Figure 4
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# Done Making Supplemental Figure 4

# %% [markdown]
# ## Supplemental Figure 5

# %%
# !python gibson_inference/figures/supplemental_figure5.py -loc1 "/content/mixed_prior_fixed/healthy-seed0-mixed" -loc2 "/content/mixed_prior_fixed/uc-seed0-mixed"
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Making Supplemental Figure 5
# meta NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# Done Making Supplemental Figure 5
